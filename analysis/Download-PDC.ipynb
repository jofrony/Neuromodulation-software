# %% [markdown]
# # Download scripts
#
# tar -zcvf archive-name.tar.gz source-directory-name

# %%
# !scp jofn@t04n27.pdc.kth.se:/cfs/klemming/nobackup/j/jofn/BasalGangliaExperiments/Neuromodulation-software/supercomputer/*.tar.gz pdc/
# Out:
# Experiment-simulation.tar.gz                  100%   12GB   8.8MB/s   22:25

# %%
# !tar -xzvf pdc/Level1.tar.gz -C pdc/
# !tar -xzvf pdc/Level2.tar.gz -C pdc/
# !tar -xzvf pdc/Level3.tar.gz -C pdc/
# !tar -xzvf pdc/Level4.tar.gz -C pdc/
# !tar -xzvf pdc/Level5.tar.gz -C pdc/
# !tar -xzvf pdc/Level6.tar.gz -C pdc/
# Out:
# Level1/pdc_network/
# Level1/pdc_network/pruning_merge_info.json
# Level1/pdc_network/network-synapses.hdf5
# Level1/pdc_network/mesh/
# Level1/pdc_network/mesh/Striatum-cube-mesh-0.000500620348030758.obj-50-cache.pickle
# Level1/pdc_network/mesh/Striatum-cube-mesh-0.000500620348030758.obj
# Level1/pdc_network/benchmark_log.json
# Level1/pdc_network/network-projection-synapses.hdf5
# Level1/pdc_network/temp/
# Level1/pdc_network/network-config.json
# Level1/pdc_network/voxels/
# Level1/pdc_network/input-spikes.hdf5
# Level1/pdc_network/input.json
# Level1/pdc_network/log/
# Level1/pdc_network/log/logFile-touch-detection.txt-68
# Level1/pdc_network/log/logFile-touch-detection.txt-34
# Level1/pdc_network/log/logFile-synapse-pruning.txt-40
# Level1/pdc_network/log/logFile-touch-detection.txt-6
# Level1/pdc_network/log/logFile-synapse-pruning.txt-8
# Level1/pdc_network/log/logFile-synapse-pruning.txt-25
# Level1/pdc_network/log/logFile-synapse-pruning.txt-51
# ...

# %%
# !tar -xzvf pdc/Experiment-simulation.tar.gz -C pdc/
# Out:
# Experiment-simulation/
# Experiment-simulation/Level6/
# Experiment-simulation/Level6/Tegner_runInput.job
# Experiment-simulation/Level6/controller_ip.txt
# Experiment-simulation/Level6/Tegner_runSnudda.sh
# Experiment-simulation/Level6/Tegner_simulate.job
# Experiment-simulation/Level6/Beskow.job
# Experiment-simulation/Level6/Tegner_run_level6.job
# Experiment-simulation/Level6/THINGSTOINSTALL.txt
# Experiment-simulation/Level6/mechanisms-modulation/
# Experiment-simulation/Level6/mechanisms-modulation/par_ggap.mod
# Experiment-simulation/Level6/mechanisms-modulation/kaf_fs.mod
# Experiment-simulation/Level6/mechanisms-modulation/caq_ms.mod
# Experiment-simulation/Level6/mechanisms-modulation/kir_ms.mod
# Experiment-simulation/Level6/mechanisms-modulation/cat32_ms.mod
# Experiment-simulation/Level6/mechanisms-modulation/kdr_fs.mod
# Experiment-simulation/Level6/mechanisms-modulation/caldyn_ms.mod
# Experiment-simulation/Level6/mechanisms-modulation/naf_ms.mod
# ...
