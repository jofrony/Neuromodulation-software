# %% [markdown]
# # Level6

# %%
from project_wide.compare_plot_traces import comparePlotTraces
simroot = 'pdc/Level6/pdc_network/simulation/'
fn = [simroot + 'network-voltage-ACh-burst-network-level6.csv',\
      simroot + 'network-voltage-ACh-pause-network-level6.csv',\
      simroot + 'network-voltage-DA-ACh-burst-network-level6.csv',\
      simroot + 'network-voltage-DA-ACh-pause-network-level6.csv',\
      simroot + 'network-voltage-DA-network-level6.csv']




root = 'pdc/Level6/pdc_network/'
nf = [root + 'network-synapses.hdf5',\
     root + 'network-synapses.hdf5',\
     root + 'network-synapses.hdf5',\
     root + 'network-synapses.hdf5',\
     root + 'network-synapses.hdf5']



nl = comparePlotTraces(fileNames=fn,\
                      networkFiles=nf,labels=['ACh burst', 'ACh pause', 'DA ACh burst', 'DA and pause', 'DA'],colours=['red','green','blue','purple','orange'],save_dir='Compare-network/')
# Out:
# Loading 10100 neurons with 3192890 synapses and 377 gap junctions
# Loading 10100 neurons with 3192890 synapses and 377 gap junctions
# Loading 10100 neurons with 3192890 synapses and 377 gap junctions
# Loading 10100 neurons with 3192890 synapses and 377 gap junctions
# Loading 10100 neurons with 3192890 synapses and 377 gap junctions

# %%
# %matplotlib notebook
plot_offset = 0  # -0.2
skip_time = 0  # 0.5
num_traces_max = 10

nl.plotTraceNeuronType(neuronType="dSPN", nTraces=10, offset=plot_offset, skipTime=skip_time)
nl.plotTraceNeuronType(neuronType="iSPN", nTraces=10, offset=plot_offset, skipTime=skip_time)
nl.plotTraceNeuronType(neuronType="FSN", nTraces=10, offset=plot_offset, skipTime=skip_time)
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/project_wide/compare_plot_traces.py:195: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# Saving to figure Compare-network/figs/Network-spikes-6-dSPN-colour.svg
# <img src="data:image/png;base64,..." width="640">
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/project_wide/compare_plot_traces.py:195: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# Saving to figure Compare-network/figs/Network-spikes-6-iSPN-colour.svg
# <img src="data:image/png;base64,..." width="640">
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/project_wide/compare_plot_traces.py:195: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# Saving to figure Compare-network/figs/Network-spikes-6-FS-colour.svg
