# %% [markdown]
# # Level3

# %%
from project_wide.compare_plot_traces import comparePlotTraces
simroot = 'pdc/Level3/pdc_network/simulation/'
fn = [simroot + 'network-voltage-ACh-burst-network-level3.csv',\
      simroot + 'network-voltage-ACh-pause-network-level3.csv',\
      simroot + 'network-voltage-DA-ACh-burst-network-level3.csv',\
      simroot + 'network-voltage-DA-ACh-pause-network-level3.csv',\
      simroot + 'network-voltage-DA-network-level3.csv',\
      simroot + 'network-voltage-control-level3.csv']




root = 'pdc/Level3/pdc_network/'
nf = [root + 'network-synapses.hdf5',\
      root + 'network-synapses.hdf5',\
      root + 'network-synapses.hdf5',\
      root + 'network-synapses.hdf5',\
      root + 'network-synapses.hdf5']

# %%
nl = comparePlotTraces(fileNames=fn,\
                      networkFiles=nf,labels=['ACh burst', 'ACh pause', 'DA ACh burst', 'DA and pause', 'DA', 'control'],colours=['red','green','blue','purple','orange','black'],save_dir='Compare-network/')
# Out:
# Loading 10100 neurons with 3190571 synapses and 378 gap junctions
# Loading 10100 neurons with 3190571 synapses and 378 gap junctions
# Loading 10100 neurons with 3190571 synapses and 378 gap junctions
# Loading 10100 neurons with 3190571 synapses and 378 gap junctions
# Loading 10100 neurons with 3190571 synapses and 378 gap junctions

# %%
# %matplotlib notebook
plot_offset = 0  # -0.2
skip_time = 0  # 0.5
num_traces_max = 10

nl.plotTraceNeuronType(neuronType="dSPN", nTraces=10, offset=plot_offset, skipTime=skip_time)
nl.plotTraceNeuronType(neuronType="iSPN", nTraces=10, offset=plot_offset, skipTime=skip_time)
nl.plotTraceNeuronType(neuronType="FSN", nTraces=10, offset=plot_offset, skipTime=skip_time)
# Out:
# <img src="data:image/png;base64,..." width="574.4444596620258">
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# Saving to figure Compare-network/figs/Network-spikes-3-dSPN-colour.svg
# <img src="data:image/png;base64,..." width="574.4444596620258">
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# Saving to figure Compare-network/figs/Network-spikes-3-iSPN-colour.svg
# <img src="data:image/png;base64,..." width="574.4444596620258">
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# Saving to figure Compare-network/figs/Network-spikes-3-FS-colour.svg
