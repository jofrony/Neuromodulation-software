# %%
from fsn_analysis import FSNanalysis
optR = FSNanalysis('fsn/str-fs-e160628_FS2-mMTC180800A-IDB-v20210210/tmgaba/dopamine/ID_0')
optR.load_current()
parameterID = optR.modulation_setup['parameterID']

# %%
optR.plot_control_current(title='D1 modulation FSN',correct_c=True,save=True,filename='control_' + str(parameterID)+'.pdf',skip=100)
# Out:
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/FSN/fsn_analysis.py:196: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/FSN/fsn_analysis.py:196: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_all_traces_current(title='D1 modulation FSN',correct_c=True,skip=500,save=True,filename='example_' + str(parameterID)+'.pdf')
# Out:
# No handles with labels found to put in legend.
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/FSN/fsn_analysis.py:166: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/FSN/fsn_analysis.py:166: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_validated_traces_with_control_current(title='D1 modulation FSN',skip=550,correct_c=True,save=True,filename='validated_' + str(parameterID)+'.pdf')
# Out:
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/FSN/fsn_analysis.py:238: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/FSN/fsn_analysis.py:238: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
