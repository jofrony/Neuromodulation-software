# %% [markdown]
# # Pack and download from PDC
#
# run....  tar -czvf folder.tar.gz folder/

# %% [markdown]
# # FSN

# %%
# !scp jofn@t04n27.pdc.kth.se:/cfs/klemming/nobackup/j/jofn/BasalGangliaExperiments/Neuromodulation/optimisation/fsn.tar.gz pdc/
# Out:
# fsn.tar.gz                                    100%   12GB   9.0MB/s   23:17

# %%
# !tar -xzvf pdc/fsn.tar.gz -C pdc/
# Out:
# FSN/fsn/
# FSN/fsn/str-fs-e160628_FS2-mMTC180800A-IDB-v20210210/
# FSN/fsn/str-fs-e160628_FS2-mMTC180800A-IDB-v20210210/tmgaba/
# FSN/fsn/str-fs-e160628_FS2-mMTC180800A-IDB-v20210210/tmgaba/dopamine/
# FSN/fsn/str-fs-e160628_FS2-mMTC180800A-IDB-v20210210/tmgaba/dopamine/ID_0/
# FSN/fsn/str-fs-e160628_FS2-mMTC180800A-IDB-v20210210/tmgaba/dopamine/ID_0/current_modulation_pass.csv
# FSN/fsn/str-fs-e160628_FS2-mMTC180800A-IDB-v20210210/tmgaba/dopamine/ID_0/current.csv
# FSN/fsn/str-fs-e160628_FS2-mMTC180800A-IDB-v20210210/tmgaba/dopamine/ID_0/modulation_pass.json
# FSN/fsn/str-fs-e160628_FS2-mMTC180800A-IDB-v20210210/tmgaba/dopamine/ID_0/modulations.json
# FSN/fsn/str-fs-e160628_FS2-mMTC180800A-IDB-v20210210/tmgaba/dopamine/ID_0/receptor-modulations.json
# FSN/fsn/str-fs-e160628_FS2-mMTC180800A-IDB-v20210210/dopamine/
# FSN/fsn/str-fs-e160628_FS2-mMTC180800A-IDB-v20210210/dopamine/ID_0/
# FSN/fsn/str-fs-e160628_FS2-mMTC180800A-IDB-v20210210/dopamine/ID_0/modulation.json
# ...
