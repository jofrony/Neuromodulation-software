# %%
from dspn_analysis import dSPNanalysis
optR = dSPNanalysis('pdc/dSPN/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20210212/acetylcholine/ID_0')
optR.load()
parameterID = optR.modulation_setup['parameterID']

# %%
optR.plot_control(title='M1/M4 modulation dSPN',save=True,filename='control_' + str(parameterID)+'.svg')
# Out:
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_all_traces(title='M1/M4  modulation dSPN',save=True,filename='example_' + str(parameterID)+'.svg')
# Out:
# No handles with labels found to put in legend.
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_validated_traces_with_control(titles='M1/M4 modulation dSPN',save=True,filename='validated_' + str(parameterID)+'.svg')
# Out:
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/dSPN/dspn_analysis.py:160: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/dSPN/dspn_analysis.py:160: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
from dspn_analysis import dSPNanalysis
optR = dSPNanalysis('pdc/dSPN/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20210212/acetylcholine/ID_1')
optR.load()
parameterID = optR.modulation_setup['parameterID']

# %%
optR.plot_control(title='M1/M4 modulation dSPN',save=True,filename='control_' + str(parameterID)+'.pdf')
# Out:
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_all_traces(title='M1/M4 modulation dSPN',save=True,filename='example_' + str(parameterID)+'.pdf')
# Out:
# No handles with labels found to put in legend.
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_validated_traces_with_control(titles='M1/M4 modulation dSPN',save=True,filename='validated_' + str(parameterID)+'.pdf')
# Out:
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/dSPN/dspn_analysis.py:160: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/dSPN/dspn_analysis.py:160: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
from dspn_analysis import dSPNanalysis
optR = dSPNanalysis('pdc/dSPN/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20210212/acetylcholine/ID_2')
optR.load()
parameterID = optR.modulation_setup['parameterID']

# %%
optR.plot_control(title='M1/M4 modulation dSPN',save=True,filename='control_' + str(parameterID)+'.pdf')
# Out:
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_all_traces(title='M1/M4 modulation dSPN',save=True,filename='example_' + str(parameterID)+'.pdf')
# Out:
# No handles with labels found to put in legend.
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_validated_traces_with_control(titles='M1/M4 modulation dSPN',save=True,filename='validated_' + str(parameterID)+'.pdf')
# Out:
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/dSPN/dspn_analysis.py:160: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/dSPN/dspn_analysis.py:160: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
from dspn_analysis import dSPNanalysis
optR = dSPNanalysis('pdc/dSPN/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20210212/acetylcholine/ID_3')
optR.load()
parameterID = optR.modulation_setup['parameterID']

# %%
optR.plot_control(title='M1/M4 modulation dSPN',save=True,filename='control_' + str(parameterID)+'.pdf')
# Out:
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_all_traces(title='M1/M4 modulation dSPN',save=True,filename='example_' + str(parameterID)+'.pdf')
# Out:
# No handles with labels found to put in legend.
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_validated_traces_with_control(titles='M1/M4 modulation dSPN',save=True,filename='validated_' + str(parameterID)+'.pdf')
# Out:
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/dSPN/dspn_analysis.py:160: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/dSPN/dspn_analysis.py:160: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
