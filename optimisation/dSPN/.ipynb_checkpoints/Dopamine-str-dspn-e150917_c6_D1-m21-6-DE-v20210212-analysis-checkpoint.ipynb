# %% [markdown]
# # Dopaminergic modulation of dSPN

# %%
from dspn_analysis import dSPNanalysis
from neuromodulation.experimental_data import experimental

# %%
dl = dSPNanalysis('pdc/dSPN/dspn/str-dspn-e150917_c6_D1-m21-6-DE-v20210212/dopamine/ID_0/')
dl.load()
dl.dopamine_analysis()


dSPNmodulation = experimental()
dSPNmodulation.define_exp(control = { "mean" : dl.get_dopamine_control()[0], "std" : 0})
dSPNmodulation.define_exp(modulated = { "mean" : dl.get_dopamine_control()[0] + dl.get_criteria()['mean'], \
                                       "std" : dl.get_criteria()['std'] * 1.5})
dSPNmodulation.define_exp(control_sim = dl.get_dopamine_control())
dSPNmodulation.define_exp(modulated_sim = [dl.num_AP_passing_analysis_traces_dopamine])
dl.plot_comparison(dSPNmodulation.experimental_data['control'],dSPNmodulation.experimental_data['control_sim'],\
                   dSPNmodulation.experimental_data['modulated'], dSPNmodulation.experimental_data['modulated_sim'],\
                   x_ticks=['Model 1'],ylabel='Number of APs',title='Dopamine modulation',num_models=1,save=True,\
                   filename='model_1.pdf' )
# Out:
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:37: UserWarning: loadtxt: Empty input file: "pdc/dSPN/dspn/str-dspn-e150917_c6_D1-m21-6-DE-v20210212/dopamine/ID_0/voltage_modulation_pass.csv"
#   self.voltage_modulation_pass = np.loadtxt(self.dir_path /  'voltage_modulation_pass.csv')
# []
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/plotting.py:76: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/plotting.py:76: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
dl.save_selected_modulation()
modulation, voltage = dl.get_final_modulation()

dl.plot_chosen_modulation()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-d513c1b34b06> in <module>
# ----> 1 dl.save_selected_modulation()
#       2 modulation, voltage = dl.get_final_modulation()
#       3
#       4 dl.plot_chosen_modulation()
#
# ~/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/dSPN/dspn_analysis.py in save_selected_modulation(self)
#     137         voltage_sub = np.take(self.voltages[1:-1],index_original,axis=0)[0]
#     138
# --> 139         index = np.where(np.transpose(results_pass)[0] ==  min(np.transpose(results_pass)[0]))
#     140
#     141         if len(index[0])>1:
#
# ValueError: min() arg is an empty sequence

# %%
dl = dSPNanalysis('pdc/dSPN/dspn/str-dspn-e150917_c6_D1-m21-6-DE-v20210212/dopamine/ID_1/')
dl.load()
dl.dopamine_analysis()


dSPNmodulation = experimental()
dSPNmodulation.define_exp(control = { "mean" : dl.get_dopamine_control()[0], "std" : 0})
dSPNmodulation.define_exp(modulated = { "mean" : dl.get_dopamine_control()[0] + dl.get_criteria()['mean'], \
                                       "std" : dl.get_criteria()['std'] * 1.5})
dSPNmodulation.define_exp(control_sim = dl.get_dopamine_control())
dSPNmodulation.define_exp(modulated_sim = [dl.num_AP_passing_analysis_traces_dopamine])
dl.plot_comparison(dSPNmodulation.experimental_data['control'],dSPNmodulation.experimental_data['control_sim'],\
                   dSPNmodulation.experimental_data['modulated'], dSPNmodulation.experimental_data['modulated_sim'],\
                   x_ticks=['Model 1'],ylabel='Number of APs',title='Dopamine modulation',num_models=1,save=True,\
                   filename='model_1.pdf' )
# Out:
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:37: UserWarning: loadtxt: Empty input file: "pdc/dSPN/dspn/str-dspn-e150917_c6_D1-m21-6-DE-v20210212/dopamine/ID_1/voltage_modulation_pass.csv"
#   self.voltage_modulation_pass = np.loadtxt(self.dir_path /  'voltage_modulation_pass.csv')
# []
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/plotting.py:76: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/plotting.py:76: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
dl.save_selected_modulation()
modulation, voltage = dl.get_final_modulation()

dl.plot_chosen_modulation()
