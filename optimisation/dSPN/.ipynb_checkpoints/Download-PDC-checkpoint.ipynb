# %% [markdown]
# # Pack and download from PDC
#
# run....  tar -czvf folder.tar.gz folder/

# %% [markdown]
# # dSPN

# %%
# !scp jofn@t04n27.pdc.kth.se:/cfs/klemming/nobackup/j/jofn/BasalGangliaExperiments/Neuromodulation/optimisation/dspn.tar.gz pdc/
# Out:
# dspn.tar.gz                                   100% 9228MB   4.2MB/s   37:01

# %%
# !tar -xzvf pdc/dspn.tar.gz -C pdc/
# Out:
# dSPN/dspn/
# dSPN/dspn/str-dspn-e150917_c6_D1-m21-6-DE-v20210212/
# dSPN/dspn/str-dspn-e150917_c6_D1-m21-6-DE-v20210212/acetylcholine/
# dSPN/dspn/str-dspn-e150917_c6_D1-m21-6-DE-v20210212/acetylcholine/ID_0/
# dSPN/dspn/str-dspn-e150917_c6_D1-m21-6-DE-v20210212/acetylcholine/ID_0/modulation.json
# dSPN/dspn/str-dspn-e150917_c6_D1-m21-6-DE-v20210212/acetylcholine/ID_0/receptor_modulation_pass.json
# dSPN/dspn/str-dspn-e150917_c6_D1-m21-6-DE-v20210212/acetylcholine/ID_0/modulation_setup.json
# dSPN/dspn/str-dspn-e150917_c6_D1-m21-6-DE-v20210212/acetylcholine/ID_0/voltage_modulation_pass.csv
# dSPN/dspn/str-dspn-e150917_c6_D1-m21-6-DE-v20210212/acetylcholine/ID_0/modulation_pass.json
# dSPN/dspn/str-dspn-e150917_c6_D1-m21-6-DE-v20210212/acetylcholine/ID_0/voltages.csv
# dSPN/dspn/str-dspn-e150917_c6_D1-m21-6-DE-v20210212/acetylcholine/ID_0/modulations.json
# dSPN/dspn/str-dspn-e150917_c6_D1-m21-6-DE-v20210212/acetylcholine/ID_1/
# ...
