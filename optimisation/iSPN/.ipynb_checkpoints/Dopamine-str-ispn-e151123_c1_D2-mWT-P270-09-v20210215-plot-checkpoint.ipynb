# %%
from ispn_analysis import iSPNanalysis
optR = iSPNanalysis('pdc/iSPN/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20210215/dopamine/ID_0/')
optR.load()
parameterID = optR.modulation_setup['parameterID']

# %%
optR.plot_control(title='D2 modulation iSPN',save=True,filename='control_' + str(parameterID)+'.pdf')
# Out:
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_all_traces(title='D2 modulation iSPN',save=True,filename='example_' + str(parameterID)+'.pdf')
# Out:
# No handles with labels found to put in legend.
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_validated_traces_with_control(titles='D2 modulation iSPN',save=True,filename='validated_' + str(parameterID)+'.pdf')
# Out:
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/iSPN/ispn_analysis.py:126: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/iSPN/ispn_analysis.py:126: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
from ispn_analysis import iSPNanalysis
optR = iSPNanalysis('pdc/iSPN/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20210215/dopamine/ID_1/')
optR.load()
parameterID = optR.modulation_setup['parameterID']

# %%
optR.plot_control(title='D2 modulation iSPN',save=True,filename='control_' + str(parameterID)+'.pdf')
# Out:
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_all_traces(title='D2 modulation iSPN',save=True,filename='example_' + str(parameterID)+'.pdf')
# Out:
# No handles with labels found to put in legend.
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_validated_traces_with_control(titles='D2 modulation iSPN',save=True,filename='validated_' + str(parameterID)+'.pdf')
# Out:
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/iSPN/ispn_analysis.py:126: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/iSPN/ispn_analysis.py:126: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
from ispn_analysis import iSPNanalysis
optR = iSPNanalysis('pdc/iSPN/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20210215/dopamine/ID_2/')
optR.load()
parameterID = optR.modulation_setup['parameterID']

# %%
optR.plot_control(title='D2 modulation iSPN',save=True,filename='control_' + str(parameterID)+'.pdf')
# Out:
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_all_traces(title='D2 modulation iSPN',save=True,filename='example_' + str(parameterID)+'.pdf')
# Out:
# No handles with labels found to put in legend.
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_validated_traces_with_control(titles='D2 modulation iSPN',save=True,filename='validated_' + str(parameterID)+'.pdf')
# Out:
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/iSPN/ispn_analysis.py:126: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/iSPN/ispn_analysis.py:126: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
from ispn_analysis import iSPNanalysis
optR = iSPNanalysis('pdc/iSPN/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20210215/dopamine/ID_3/')
optR.load()
parameterID = optR.modulation_setup['parameterID']

# %%
optR.plot_control(title='D2 modulation iSPN',save=True,filename='control_' + str(parameterID)+'.pdf')
# Out:
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_all_traces(title='D2 modulation iSPN',save=True,filename='example_' + str(parameterID)+'.pdf')
# Out:
# No handles with labels found to put in legend.
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_validated_traces_with_control(titles='D2 modulation iSPN',save=True,filename='validated_' + str(parameterID)+'.pdf')
# Out:
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/iSPN/ispn_analysis.py:126: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/iSPN/ispn_analysis.py:126: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
from ispn_analysis import iSPNanalysis
optR = iSPNanalysis('pdc/iSPN/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20210215/dopamine/ID_4/')
optR.load()
parameterID = optR.modulation_setup['parameterID']

# %%
optR.plot_control(title='D2 modulation iSPN',save=True,filename='control_' + str(parameterID)+'.pdf')
# Out:
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_all_traces(title='D2 modulation iSPN',save=True,filename='example_' + str(parameterID)+'.pdf')
# Out:
# No handles with labels found to put in legend.
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_validated_traces_with_control(titles='D2 modulation iSPN',save=True,filename='validated_' + str(parameterID)+'.pdf')
# Out:
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/iSPN/ispn_analysis.py:126: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/iSPN/ispn_analysis.py:126: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
from ispn_analysis import iSPNanalysis
optR = iSPNanalysis('pdc/iSPN/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20210215/dopamine/ID_5/')
optR.load()
parameterID = optR.modulation_setup['parameterID']

# %%
optR.plot_control(title='D2 modulation iSPN',save=True,filename='control_' + str(parameterID)+'.pdf')
# Out:
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_all_traces(title='D2 modulation iSPN',save=True,filename='example_' + str(parameterID)+'.pdf')
# Out:
# No handles with labels found to put in legend.
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_validated_traces_with_control(titles='D2 modulation iSPN',save=True,filename='validated_' + str(parameterID)+'.pdf')
# Out:
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/iSPN/ispn_analysis.py:126: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/iSPN/ispn_analysis.py:126: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
from ispn_analysis import iSPNanalysis
optR = iSPNanalysis('pdc/iSPN/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20210215/dopamine/ID_6/')
optR.load()
parameterID = optR.modulation_setup['parameterID']

# %%
optR.plot_control(title='D2 modulation iSPN',save=True,filename='control_' + str(parameterID)+'.pdf')
# Out:
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:58: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_all_traces(title='D2 modulation iSPN',save=True,filename='example_' + str(parameterID)+'.pdf')
# Out:
# No handles with labels found to put in legend.
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/neuromodulation/analysis.py:90: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)

# %%
optR.plot_validated_traces_with_control(titles='D2 modulation iSPN',save=True,filename='validated_' + str(parameterID)+'.pdf')
# Out:
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/iSPN/ispn_analysis.py:126: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/iSPN/ispn_analysis.py:126: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   frameon=None, metadata=None)
