# %% [markdown]
# # iSPN optimisation - Dopaminergic modulation

# %% [markdown]
# Set the modulation for dopaminergic D2 receptor modulation

# %%
from neuromodulation.modulation_set import defineModulation

# %% [markdown]
# ### Neuromodulation set up

# %% [markdown]
# #### parameter ID : 0

# %%
cellTypefolder = '../../single_cell_models/HBP-2021Q1/iSPN/str-ispn-e150908_c4_D2-m51-5-DE-v20210215/'

out_put_dir = 'ispn/str-ispn-e150908_c4_D2-m51-5-DE-v20210215/'

parameterID = 0

ModSet = defineModulation(parameterID = parameterID)
ModSet.cell_name('iSPN')
ModSet.define_neuromodulation(modulationA = "dopamine")
ModSet.new_modulation_dir(out_put_dir)
ModSet.tstop = 1000
ModSet.set_time_step(dt=0.025)
ModSet.population = 200
ModSet.cellDir = cellTypefolder

ModSet.define_modulation_parameter('naf','dopamine','all', [0.95,1.1])
ModSet.define_modulation_parameter('kas','dopamine','all', [1,1.1])
ModSet.define_modulation_parameter('kaf','dopamine','somatic', [1,1.1])
ModSet.define_modulation_parameter('kaf','dopamine','basal', [1,1.1])
ModSet.define_modulation_parameter('kir','dopamine','somatic', [0.8,1])
ModSet.define_modulation_parameter('kir','dopamine','basal', [0.8,1])
ModSet.define_modulation_parameter('cal12','dopamine','somatic', [0.7,0.8])
ModSet.define_modulation_parameter('cal12','dopamine','basal', [0.7,0.8])
ModSet.define_modulation_parameter('cal13','dopamine','somatic', [0.7,0.8])
ModSet.define_modulation_parameter('cal13','dopamine','basal', [0.7,0.8])
ModSet.define_modulation_parameter('can','dopamine','somatic', [0.9,1.0])
ModSet.define_modulation_parameter('car','dopamine','somatic', [0.6,0.8])
ModSet.define_modulation_parameter('car','dopamine','basal', [0.8,0.8])
ModSet.define_modulation_function(modulation_function = {"function" : "bath_application","gmax" : 1})

ModSet.define_protocol(typeEx = 'current_clamp', parameters = {"start" : 0,"duration" : 1000 , "amp" : 0.25})

ModSet.define_protocol(typeEx = 'current_clamp', parameters = {"start" : 200,"duration" : 500 , "amp" : 0.04})

ModSet.define_selection_criteria(function = "number_AP_decrease", criteria ={ "selection" : {"mean" : 1.5, "std" : 1, "threshold":1.5}, "parameters" : { "tstart":200,"tstop": 700}})

ModSet.save_modulation_setup()
ModSet.save_modulation()
ModSet.neuromodulationDir
# Out:
# PosixPath('ispn/str-ispn-e150908_c4_D2-m51-5-DE-v20210215/dopamine/ID_0')

# %% [markdown]
# #### parameter ID : 1

# %%
cellTypefolder = '../../single_cell_models/HBP-2021Q1/iSPN/str-ispn-e150908_c4_D2-m51-5-DE-v20210215/'

out_put_dir = 'ispn/str-ispn-e150908_c4_D2-m51-5-DE-v20210215/'

parameterID = 1

ModSet = defineModulation(parameterID = parameterID)
ModSet.cell_name('iSPN')
ModSet.define_neuromodulation(modulationA = "dopamine")
ModSet.new_modulation_dir(out_put_dir)
ModSet.tstop = 1000
ModSet.set_time_step(dt=0.025)
ModSet.population = 200
ModSet.cellDir = cellTypefolder

ModSet.define_modulation_parameter('naf','dopamine','all', [0.95,1.1])
ModSet.define_modulation_parameter('kas','dopamine','all', [1,1.1])
ModSet.define_modulation_parameter('kaf','dopamine','somatic', [1,1.1])
ModSet.define_modulation_parameter('kaf','dopamine','basal', [1,1.1])
ModSet.define_modulation_parameter('kir','dopamine','somatic', [0.8,1])
ModSet.define_modulation_parameter('kir','dopamine','basal', [0.8,1])
ModSet.define_modulation_parameter('cal12','dopamine','somatic', [0.7,0.8])
ModSet.define_modulation_parameter('cal12','dopamine','basal', [0.7,0.8])
ModSet.define_modulation_parameter('cal13','dopamine','somatic', [0.7,0.8])
ModSet.define_modulation_parameter('cal13','dopamine','basal', [0.7,0.8])
ModSet.define_modulation_parameter('can','dopamine','somatic', [0.9,1.0])
ModSet.define_modulation_parameter('car','dopamine','somatic', [0.6,0.8])
ModSet.define_modulation_parameter('car','dopamine','basal', [0.8,0.8])
ModSet.define_modulation_function(modulation_function = {"function" : "bath_application","gmax" : 1})

ModSet.define_protocol(typeEx = 'current_clamp', parameters = {"start" : 0,"duration" : 1000 , "amp" : 0.25})

ModSet.define_protocol(typeEx = 'current_clamp', parameters = {"start" : 200,"duration" : 500 , "amp" : 0.04})

ModSet.define_selection_criteria(function = "number_AP_decrease", criteria ={ "selection" : {"mean" : 1.5, "std" : 1, "threshold":1.5}, "parameters" : { "tstart":200,"tstop": 700}})

ModSet.save_modulation_setup()
ModSet.save_modulation()
ModSet.neuromodulationDir
# Out:
# PosixPath('ispn/str-ispn-e150908_c4_D2-m51-5-DE-v20210215/dopamine/ID_1')

# %% [markdown]
# #### parameter ID : 2

# %%
cellTypefolder = '../../single_cell_models/HBP-2021Q1/iSPN/str-ispn-e150908_c4_D2-m51-5-DE-v20210215/'

out_put_dir = 'ispn/str-ispn-e150908_c4_D2-m51-5-DE-v20210215/'

parameterID = 2

ModSet = defineModulation(parameterID = parameterID)
ModSet.cell_name('iSPN')
ModSet.define_neuromodulation(modulationA = "dopamine")
ModSet.new_modulation_dir(out_put_dir)
ModSet.tstop = 1000
ModSet.set_time_step(dt=0.025)
ModSet.population = 200
ModSet.cellDir = cellTypefolder

ModSet.define_modulation_parameter('naf','dopamine','all', [0.95,1.1])
ModSet.define_modulation_parameter('kas','dopamine','all', [1,1.1])
ModSet.define_modulation_parameter('kaf','dopamine','somatic', [1,1.1])
ModSet.define_modulation_parameter('kaf','dopamine','basal', [1,1.1])
ModSet.define_modulation_parameter('kir','dopamine','somatic', [0.8,1])
ModSet.define_modulation_parameter('kir','dopamine','basal', [0.8,1])
ModSet.define_modulation_parameter('cal12','dopamine','somatic', [0.7,0.8])
ModSet.define_modulation_parameter('cal12','dopamine','basal', [0.7,0.8])
ModSet.define_modulation_parameter('cal13','dopamine','somatic', [0.7,0.8])
ModSet.define_modulation_parameter('cal13','dopamine','basal', [0.7,0.8])
ModSet.define_modulation_parameter('can','dopamine','somatic', [0.9,1.0])
ModSet.define_modulation_parameter('car','dopamine','somatic', [0.6,0.8])
ModSet.define_modulation_parameter('car','dopamine','basal', [0.8,0.8])
ModSet.define_modulation_function(modulation_function = {"function" : "bath_application","gmax" : 1})

ModSet.define_protocol(typeEx = 'current_clamp', parameters = {"start" : 0,"duration" : 1000 , "amp" : 0.25})

ModSet.define_protocol(typeEx = 'current_clamp', parameters = {"start" : 200,"duration" : 500 , "amp" : 0.04})

ModSet.define_selection_criteria(function = "number_AP_decrease", criteria ={ "selection" : {"mean" : 1.5, "std" : 1, "threshold":1.5}, "parameters" : { "tstart":200,"tstop": 700}})

ModSet.save_modulation_setup()
ModSet.save_modulation()
ModSet.neuromodulationDir
# Out:
# PosixPath('ispn/str-ispn-e150908_c4_D2-m51-5-DE-v20210215/dopamine/ID_2')

# %% [markdown]
# #### parameter ID : 3

# %%
cellTypefolder = '../../single_cell_models/HBP-2021Q1/iSPN/str-ispn-e150908_c4_D2-m51-5-DE-v20210215/'

out_put_dir = 'ispn/str-ispn-e150908_c4_D2-m51-5-DE-v20210215/'

parameterID = 3

ModSet = defineModulation(parameterID = parameterID)
ModSet.cell_name('iSPN')
ModSet.define_neuromodulation(modulationA = "dopamine")
ModSet.new_modulation_dir(out_put_dir)
ModSet.tstop = 1000
ModSet.set_time_step(dt=0.025)
ModSet.population = 200
ModSet.cellDir = cellTypefolder

ModSet.define_modulation_parameter('naf','dopamine','all', [0.95,1.1])
ModSet.define_modulation_parameter('kas','dopamine','all', [1,1.1])
ModSet.define_modulation_parameter('kaf','dopamine','somatic', [1,1.1])
ModSet.define_modulation_parameter('kaf','dopamine','basal', [1,1.1])
ModSet.define_modulation_parameter('kir','dopamine','somatic', [0.8,1])
ModSet.define_modulation_parameter('kir','dopamine','basal', [0.8,1])
ModSet.define_modulation_parameter('cal12','dopamine','somatic', [0.7,0.8])
ModSet.define_modulation_parameter('cal12','dopamine','basal', [0.7,0.8])
ModSet.define_modulation_parameter('cal13','dopamine','somatic', [0.7,0.8])
ModSet.define_modulation_parameter('cal13','dopamine','basal', [0.7,0.8])
ModSet.define_modulation_parameter('can','dopamine','somatic', [0.9,1.0])
ModSet.define_modulation_parameter('car','dopamine','somatic', [0.6,0.8])
ModSet.define_modulation_parameter('car','dopamine','basal', [0.8,0.8])
ModSet.define_modulation_function(modulation_function = {"function" : "bath_application","gmax" : 1})

ModSet.define_protocol(typeEx = 'current_clamp', parameters = {"start" : 0,"duration" : 1000 , "amp" : 0.25})

ModSet.define_protocol(typeEx = 'current_clamp', parameters = {"start" : 200,"duration" : 500 , "amp" : 0.04})

ModSet.define_selection_criteria(function = "number_AP_decrease", criteria ={ "selection" : {"mean" : 1.5, "std" : 1, "threshold":1.5}, "parameters" : { "tstart":200,"tstop": 700}})

ModSet.save_modulation_setup()
ModSet.save_modulation()
ModSet.neuromodulationDir
# Out:
# PosixPath('ispn/str-ispn-e150908_c4_D2-m51-5-DE-v20210215/dopamine/ID_3')

# %% [markdown]
# #### parameter ID : 4

# %%
cellTypefolder = '../../single_cell_models/HBP-2021Q1/iSPN/str-ispn-e150908_c4_D2-m51-5-DE-v20210215/'

out_put_dir = 'ispn/str-ispn-e150908_c4_D2-m51-5-DE-v20210215/'

parameterID = 4

ModSet = defineModulation(parameterID = parameterID)
ModSet.cell_name('iSPN')
ModSet.define_neuromodulation(modulationA = "dopamine")
ModSet.new_modulation_dir(out_put_dir)
ModSet.tstop = 1000
ModSet.set_time_step(dt=0.025)
ModSet.population = 200
ModSet.cellDir = cellTypefolder

ModSet.define_modulation_parameter('naf','dopamine','all', [0.95,1.1])
ModSet.define_modulation_parameter('kas','dopamine','all', [1,1.1])
ModSet.define_modulation_parameter('kaf','dopamine','somatic', [1,1.1])
ModSet.define_modulation_parameter('kaf','dopamine','basal', [1,1.1])
ModSet.define_modulation_parameter('kir','dopamine','somatic', [0.8,1])
ModSet.define_modulation_parameter('kir','dopamine','basal', [0.8,1])
ModSet.define_modulation_parameter('cal12','dopamine','somatic', [0.7,0.8])
ModSet.define_modulation_parameter('cal12','dopamine','basal', [0.7,0.8])
ModSet.define_modulation_parameter('cal13','dopamine','somatic', [0.7,0.8])
ModSet.define_modulation_parameter('cal13','dopamine','basal', [0.7,0.8])
ModSet.define_modulation_parameter('can','dopamine','somatic', [0.9,1.0])
ModSet.define_modulation_parameter('car','dopamine','somatic', [0.6,0.8])
ModSet.define_modulation_parameter('car','dopamine','basal', [0.8,0.8])
ModSet.define_modulation_function(modulation_function = {"function" : "bath_application","gmax" : 1})

ModSet.define_protocol(typeEx = 'current_clamp', parameters = {"start" : 0,"duration" : 1000 , "amp" : 0.25})

ModSet.define_protocol(typeEx = 'current_clamp', parameters = {"start" : 200,"duration" : 500 , "amp" : 0.04})

ModSet.define_selection_criteria(function = "number_AP_decrease", criteria ={ "selection" : {"mean" : 1.5, "std" : 1, "threshold":1.5}, "parameters" : { "tstart":200,"tstop": 700}})

ModSet.save_modulation_setup()
ModSet.save_modulation()
ModSet.neuromodulationDir
# Out:
# PosixPath('ispn/str-ispn-e150908_c4_D2-m51-5-DE-v20210215/dopamine/ID_4')

# %% [markdown]
# #### parameter ID : 5

# %%
cellTypefolder = '../../single_cell_models/HBP-2021Q1/iSPN/str-ispn-e150908_c4_D2-m51-5-DE-v20210215/'

out_put_dir = 'ispn/str-ispn-e150908_c4_D2-m51-5-DE-v20210215/'

parameterID = 5

ModSet = defineModulation(parameterID = parameterID)
ModSet.cell_name('iSPN')
ModSet.define_neuromodulation(modulationA = "dopamine")
ModSet.new_modulation_dir(out_put_dir)
ModSet.tstop = 1000
ModSet.set_time_step(dt=0.025)
ModSet.population = 200
ModSet.cellDir = cellTypefolder

ModSet.define_modulation_parameter('naf','dopamine','all', [0.95,1.1])
ModSet.define_modulation_parameter('kas','dopamine','all', [1,1.1])
ModSet.define_modulation_parameter('kaf','dopamine','somatic', [1,1.1])
ModSet.define_modulation_parameter('kaf','dopamine','basal', [1,1.1])
ModSet.define_modulation_parameter('kir','dopamine','somatic', [0.8,1])
ModSet.define_modulation_parameter('kir','dopamine','basal', [0.8,1])
ModSet.define_modulation_parameter('cal12','dopamine','somatic', [0.7,0.8])
ModSet.define_modulation_parameter('cal12','dopamine','basal', [0.7,0.8])
ModSet.define_modulation_parameter('cal13','dopamine','somatic', [0.7,0.8])
ModSet.define_modulation_parameter('cal13','dopamine','basal', [0.7,0.8])
ModSet.define_modulation_parameter('can','dopamine','somatic', [0.9,1.0])
ModSet.define_modulation_parameter('car','dopamine','somatic', [0.6,0.8])
ModSet.define_modulation_parameter('car','dopamine','basal', [0.8,0.8])
ModSet.define_modulation_function(modulation_function = {"function" : "bath_application","gmax" : 1})

ModSet.define_protocol(typeEx = 'current_clamp', parameters = {"start" : 0,"duration" : 1000 , "amp" : 0.25})

ModSet.define_protocol(typeEx = 'current_clamp', parameters = {"start" : 200,"duration" : 500 , "amp" : 0.04})

ModSet.define_selection_criteria(function = "number_AP_decrease", criteria ={ "selection" : {"mean" : 1.5, "std" : 1, "threshold":1.5}, "parameters" : { "tstart":200,"tstop": 700}})

ModSet.save_modulation_setup()
ModSet.save_modulation()
ModSet.neuromodulationDir
# Out:
# PosixPath('ispn/str-ispn-e150908_c4_D2-m51-5-DE-v20210215/dopamine/ID_5')

# %% [markdown]
# # Literature

# %% [markdown]
# Planert et al 2013

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Janssen et al 2009 - J. Neurosci., April 22, 2009 • 29(16):5116 –5126

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Optimise the modulated models

# %%
# !nrnivmodl mechanisms-ispn/
# Out:
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/optimisation/iSPN
# ls: cannot access 'mechanisms-ispn//*.inc': No such file or directory
# mechanisms-ispn//bk.mod mechanisms-ispn//cadyn.mod mechanisms-ispn//cal12.mod mechanisms-ispn//cal13.mod mechanisms-ispn//caldyn.mod mechanisms-ispn//can.mod mechanisms-ispn//caq.mod mechanisms-ispn//car.mod mechanisms-ispn//cat32.mod mechanisms-ispn//cat33.mod mechanisms-ispn//concACh.mod mechanisms-ispn//concDA.mod mechanisms-ispn//Im.mod mechanisms-ispn//kaf.mod mechanisms-ispn//kas.mod mechanisms-ispn//kdr.mod mechanisms-ispn//kir.mod mechanisms-ispn//naf.mod mechanisms-ispn//NO.mod mechanisms-ispn//sk.mod mechanisms-ispn//tmgabaa.mod mechanisms-ispn//tmglut_M1RH_D1.mod mechanisms-ispn//tmglut.mod mechanisms-ispn//vecevent.mod
# ...

# %%
parameterIDmodel = 'ispn/str-ispn-e150908_c4_D2-m51-5-DE-v20210215/dopamine/ID_' + str(parameterID)
seed = 12345

# %%
# !mpiexec -n 4 python optimise_ispn.py $parameterIDmodel $seed
