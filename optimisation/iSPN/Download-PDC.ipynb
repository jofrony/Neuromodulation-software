# %% [markdown]
# # Pack and download from PDC
#
# run....  tar -czvf folder.tar.gz folder/

# %% [markdown]
# # iSPN

# %%
# !scp jofn@t04n27.pdc.kth.se:/cfs/klemming/nobackup/j/jofn/BasalGangliaExperiments/Neuromodulation/optimisation/ispn.tar.gz pdc/
# Out:
# ispn.tar.gz                                   100%   21GB   9.5MB/s   37:22

# %%
# !tar -xzvf pdc/ispn.tar.gz -C pdc/
# Out:
# iSPN/ispn/
# iSPN/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20210215/
# iSPN/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20210215/acetylcholine/
# iSPN/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20210215/acetylcholine/ID_0/
# iSPN/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20210215/acetylcholine/ID_0/modulation.json
# iSPN/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20210215/acetylcholine/ID_0/receptor_modulation_pass.json
# iSPN/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20210215/acetylcholine/ID_0/modulation_setup.json
# iSPN/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20210215/acetylcholine/ID_0/voltage_modulation_pass.csv
# iSPN/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20210215/acetylcholine/ID_0/modulation_pass.json
# iSPN/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20210215/acetylcholine/ID_0/voltages.csv
# iSPN/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20210215/acetylcholine/ID_0/modulations.json
# iSPN/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20210215/acetylcholine/ID_1/
# ...
