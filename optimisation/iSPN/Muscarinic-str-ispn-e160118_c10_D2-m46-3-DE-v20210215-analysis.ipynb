# %% [markdown]
# # Muscarinic modulation of iSPN

# %%
from ispn_analysis import iSPNanalysis
from neuromodulation.experimental_data import experimental

# %%
dl = iSPNanalysis('pdc/iSPN/ispn/str-ispn-e160118_c10_D2-m46-3-DE-v20210215/acetylcholine/ID_0/')
dl.load()
dl.muscarinic_analysis()


iSPNmodulation = experimental()
iSPNmodulation.define_exp(control = { "mean" : dl.get_muscarinic_control()[0], "std" : 0})
iSPNmodulation.define_exp(modulated = { "mean" : dl.get_muscarinic_control()[0] + dl.get_criteria()['mean'], \
                                       "std" : dl.get_criteria()['std'] * 1.5})
iSPNmodulation.define_exp(control_sim = dl.get_muscarinic_control())
iSPNmodulation.define_exp(modulated_sim = [dl.num_AP_passing_analysis_traces_muscarinic])
dl.plot_comparison(iSPNmodulation.experimental_data['control'],iSPNmodulation.experimental_data['control_sim'],\
                   iSPNmodulation.experimental_data['modulated'], iSPNmodulation.experimental_data['modulated_sim'],\
                   x_ticks=['Model 1'],ylabel='Number of APs',title='Dopamine modulation',num_models=1,save=True,\
                   filename='model_1.pdf' )
# Out:
# [11 11 11 11 11 11 11 11 11 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12
#  12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12
#  12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12
#  12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12
#  12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12
#  12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12
#  12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12 12
#  12 12 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13
#  13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13
#  13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13
#  13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13
#  13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13
#  13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13 13
# ...

# %%
dl.save_selected_modulation()
modulation, voltage = dl.get_final_modulation()

dl.plot_chosen_modulation()
