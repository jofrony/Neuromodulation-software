# %% [markdown]
# # Neuromodulation dopamine and acetylcholine - acetylcholine  - adaptive - spiking presynaptic neuron

# %% [markdown]
# To simulate single neuromodulator in Snudda, firstly, the parameters from Neuromodcell have to been saved in modulations.json and placed in the model dircetory.
#
#
# To install snudda, follow the instructions at https://github.com/Hjorthmedh/Snudda/wiki/1.-User-installation
#
# Following installation, the code below will set up the network and the neuromodulatory modulation.

# %% [markdown]
# To set the $DATA parameter for snudda,

# %%
import os
os.environ["SNUDDA_DATA"] = "data"

# %% [markdown]
# This should be set to the directory where neurons, synapses and other parameters for the network have been placed. Look at the 'data' directory for referenece

# %% [markdown]
# Set the directory for where the neurons for the striatum (in this example) are saved

# %%
neurons_dir = os.path.abspath(os.path.join("data","neurons"))

# %% [markdown]
# We wrote a specific neuromodulation init (based on snuddas init.py), to load the synapses which have had the modulation parameters included into the parameter sets as well as add SNc and dopaminergic neurons to the simulation

# %%
from code.neuromodulationInitSNc import neuromodulationInit

network_path = "dopamine-acetylcholine-adaptive-trial-network"
config_name= os.path.join(network_path,"network-config.json")
cnc = neuromodulationInit(config_file=config_name,random_seed=12345)

cnc.define_striatum_neuromodulation(num_dSPN=5, num_iSPN=5,volume_type="cube",neurons_dir=neurons_dir)
cnc.define_snc(nNeurons=4,neuron_dir=neurons_dir)
dirName = os.path.dirname(config_name)

if not os.path.exists(dirName):
    os.makedirs(dirName)
    
cnc.write_json(config_name)
# Out:
# Using cube for striatum
# Adding neurons: dSPN from dir /home/jofrony/Documents/Repositories/BasalGangliaPublications/Neuromodulation-software/examples/data/neurons/striatum/dspn
# Adding neurons: iSPN from dir /home/jofrony/Documents/Repositories/BasalGangliaPublications/Neuromodulation-software/examples/data/neurons/striatum/ispn
# Adding neurons: DopaminergicAxon from dir /home/jofrony/Documents/Repositories/BasalGangliaPublications/Neuromodulation-software/examples/data/neurons/SNc
# Writing dopamine-acetylcholine-adaptive-trial-network/network-config.json

# %% [markdown]
# Then we place the neurons within the network (as we are running this locally we are limiting the network to 21 neurons). We then detect the potential synapses (by appositions between axons and dendrites) and then remove (prune) to reproduce the reported connectivity.

# %%
from snudda.place import SnuddaPlace
sp = SnuddaPlace(network_path=network_path)
sp.parse_config()
sp.write_data()

from snudda.detect import SnuddaDetect

sd = SnuddaDetect(network_path=network_path)
sd.detect()

from snudda.prune import SnuddaPrune

sp = SnuddaPrune(network_path=network_path)
sp.prune()

from snudda.plotting.plot_network import PlotNetwork
pn = PlotNetwork(network_path)
pn.plot()
pn.close()
# Out:
# No d_view specified, running distribute neurons in serial
# Processing hyper voxel : 20/64 (14 neurons)
# Processing hyper voxel : 1/64 (14 neurons)
# Processing hyper voxel : 21/64 (14 neurons)
# Processing hyper voxel : 4/64 (14 neurons)
# Processing hyper voxel : 5/64 (14 neurons)
# Processing hyper voxel : 17/64 (14 neurons)
# Processing hyper voxel : 16/64 (14 neurons)
# Processing hyper voxel : 0/64 (13 neurons)
# Processing hyper voxel : 2/64 (7 neurons)
# Processing hyper voxel : 25/64 (5 neurons)
# Processing hyper voxel : 8/64 (5 neurons)
# Processing hyper voxel : 6/64 (5 neurons)
# Processing hyper voxel : 18/64 (5 neurons)
# Processing hyper voxel : 24/64 (5 neurons)
# Processing hyper voxel : 9/64 (5 neurons)
# Processing hyper voxel : 36/64 (5 neurons)
# Processing hyper voxel : 38/64 (4 neurons)
# Processing hyper voxel : 37/64 (4 neurons)
# Processing hyper voxel : 34/64 (4 neurons)
# Processing hyper voxel : 10/64 (4 neurons)
# Processing hyper voxel : 32/64 (4 neurons)
# Processing hyper voxel : 26/64 (4 neurons)
# Processing hyper voxel : 22/64 (4 neurons)
# Processing hyper voxel : 40/64 (4 neurons)
# Processing hyper voxel : 33/64 (4 neurons)
# Processing hyper voxel : 41/64 (4 neurons)
# SnuddaPrune is now available when doing import snudda.detect
# Please update to `from snudda.detect import SnuddaPrune`
# Read 12942 out of total 12942 synapses
# Loading 14 neurons with 11153 synapses and 0 gap junctions

# %% [markdown]
# Following the assembly of the circuit, we set up the neuromodulatory connections which are needed for adaptive neuromodulation. The user defines the connections which are needed and the name of the connector, here we chose concACh and concDA. For the control, we set the weight as 0, otherwise 1e-2

# %%
# Set up neuromodulation per synapse

from snudda.neuromodulation.modulation_synapse import  NeuromodulationSynapse

sw = NeuromodulationSynapse()
sw.set_weight(weight=1e-1)

# Acetylcholine

sw.set_connection_type(connector="concACh", neuromodulation_key="ACh")

sw.add_cell_modulation(neuromodulation_key="ACh",
                       cell="dSPN",
                       ion_channels={
                           "soma": ["kir_ms", "cal12_ms", "cal13_ms", "can_ms", "Im_ms"],
                           "dendrite": ["kir_ms", "cal12_ms", "cal13_ms"]},
                       type_connection="spiking-concentration")

sw.add_cell_modulation(neuromodulation_key="ACh",
                       cell="iSPN",
                       ion_channels={
                           "soma": ["kir_ms","cal12_ms","cal13_ms","can_ms"],
                           "dendrite": ["kir_ms","cal12_ms","cal13_ms"]},
                       type_connection="spiking-concentration")

# Dopamine

sw.set_connection_type(connector="concDA", neuromodulation_key="DA")

sw.add_cell_modulation(neuromodulation_key="DA",
                       cell="dSPN",
                       ion_channels={
                           "soma": ["kas_ms", "kaf_ms", "can_ms"],
                           "dendrite": ["kaf_ms", "kas_ms"],
                           "axon": []},
                       receptors={"tmGabaA": {"maxMod": 0.8},
                                  "tmGlut": {"maxMod_AMPA": 1.2,
                                             "maxMod_NMDA": 1.3,
                                             "failRate": 0.7}},
                       extrinsic=["CorticalBase", "CorticalSignal", "Thalamic"],
                       type_connection="spiking-concentration")

sw.save(dir_path=os.path.join("data","modulation"), name="DA-ACh.json")

# %%
# Set up neuromodulation per synapse

from snudda.neuromodulation.modulation_synapse import  NeuromodulationSynapse

sw = NeuromodulationSynapse()
sw.set_weight(weight=0)

# Acetylcholine

sw.set_connection_type(connector="concACh", neuromodulation_key="ACh")

sw.add_cell_modulation(neuromodulation_key="ACh",
                       cell="dSPN",
                       ion_channels={
                           "soma": ["kir_ms", "cal12_ms", "cal13_ms", "can_ms", "Im_ms"],
                           "dendrite": ["kir_ms", "cal12_ms", "cal13_ms"]},
                       type_connection="spiking-concentration")

sw.add_cell_modulation(neuromodulation_key="ACh",
                       cell="iSPN",
                       ion_channels={
                           "soma": ["kir_ms","cal12_ms","cal13_ms","can_ms"],
                           "dendrite": ["kir_ms","cal12_ms","cal13_ms"]},
                       type_connection="spiking-concentration")

# Dopamine

sw.set_connection_type(connector="concDA", neuromodulation_key="DA")

sw.add_cell_modulation(neuromodulation_key="DA",
                       cell="dSPN",
                       ion_channels={
                           "soma": ["kas_ms", "kaf_ms", "can_ms"],
                           "dendrite": ["kaf_ms", "kas_ms"]},
                       receptors={"tmGabaA": {"maxMod": 0.8},
                                  "tmGlut": {"maxMod_AMPA": 1.2,
                                             "maxMod_NMDA": 1.3,
                                             "failRate": 0.7}},
                       extrinsic=["CorticalBase", "CorticalSignal", "Thalamic"],
                       type_connection="spiking-concentration")

sw.save(dir_path=os.path.join("data","modulation"), name="DA-ACh-control.json")

# %% [markdown]
# Compile the mechanisms used in the simulation

# %%
# !rm -r x86_64/
# !nrnivmodl mechanisms-modulation-ptr/
# Out:
# Creating x86_64 directory for .o files.
#
# /home/jofrony/Documents/Repositories/BasalGangliaPublications/Neuromodulation-software/examples
# ls: cannot access 'mechanisms-modulation-ptr//*.inc': No such file or directory
# mechanisms-modulation-ptr//bk_ch.mod mechanisms-modulation-ptr//bk_fs.mod mechanisms-modulation-ptr//bk_ms.mod mechanisms-modulation-ptr//ca_ch.mod mechanisms-modulation-ptr//cadyn_fs.mod mechanisms-modulation-ptr//cadyn_ms.mod mechanisms-modulation-ptr//cal12_ms.mod mechanisms-modulation-ptr//cal12_ms_ptr.mod mechanisms-modulation-ptr//cal13_ms.mod mechanisms-modulation-ptr//cal13_ms_ptr.mod mechanisms-modulation-ptr//cal_ch.mod mechanisms-modulation-ptr//cal_ch_ptr.mod mechanisms-modulation-ptr//caldyn_ms.mod mechanisms-modulation-ptr//can_fs.mod mechanisms-modulation-ptr//can_ms.mod mechanisms-modulation-ptr//can_ms_ptr.mod mechanisms-modulation-ptr//cap_ch.mod mechanisms-modulation-ptr//cap_ch_ptr.mod mechanisms-modulation-ptr//caq_fs.mod mechanisms-modulation-ptr//caq_ms.mod mechanisms-modulation-ptr//car_fs.mod mechanisms-modulation-ptr//car_ms.mod mechanisms-modulation-ptr//car_ms_ptr.mod mechanisms-modulation-ptr//cat32_ms.mod mechanisms-modulation-ptr//cat33_ms.mod mechanisms-modulation-ptr//concACh.mod mechanisms-modulation-ptr//concDA.mod mechanisms-modulation-ptr//hcn12_ch.mod mechanisms-modulation-ptr//hcn12_ch_ptr.mod mechanisms-modulation-ptr//hd_lts.mod mechanisms-modulation-ptr//hd_lts_ptr.mod mechanisms-modulation-ptr//im_lts.mod mechanisms-modulation-ptr//im_lts_ptr.mod mechanisms-modulation-ptr//Im_ms.mod mechanisms-modulation-ptr//Im_ms_ptr.mod mechanisms-modulation-ptr//it_lts.mod mechanisms-modulation-ptr//it_lts_ptr.mod mechanisms-modulation-ptr//kaf_fs.mod mechanisms-modulation-ptr//kaf_fs_ptr.mod mechanisms-modulation-ptr//kaf_lts.mod mechanisms-modulation-ptr//kaf_lts_ptr.mod mechanisms-modulation-ptr//kaf_ms.mod mechanisms-modulation-ptr//kaf_ms_ptr.mod mechanisms-modulation-ptr//kas_fs.mod mechanisms-modulation-ptr//kas_fs_ptr.mod mechanisms-modulation-ptr//kas_ms.mod mechanisms-modulation-ptr//kas_ms_ptr.mod mechanisms-modulation-ptr//kcnq_ch.mod mechanisms-modulation-ptr//kdb_lts.mod mechanisms-modulation-ptr//kdrbca1_lts.mod mechanisms-modulation-ptr//kdr_fs.mod mechanisms-modulation-ptr//kdr_lts.mod mechanisms-modulation-ptr//kdr_lts_ptr.mod mechanisms-modulation-ptr//kdr_ms.mod mechanisms-modulation-ptr//kir23_ch.mod mechanisms-modulation-ptr//kir23_ch_ptr.mod mechanisms-modulation-ptr//kir23_lts.mod mechanisms-modulation-ptr//kir23_lts_ptr.mod mechanisms-modulation-ptr//kir2_ch.mod mechanisms-modulation-ptr//kir2_ch_ptr.mod mechanisms-modulation-ptr//kir_fs.mod mechanisms-modulation-ptr//kir_fs_ptr.mod mechanisms-modulation-ptr//kir_ms.mod mechanisms-modulation-ptr//kir_ms_ptr.mod mechanisms-modulation-ptr//kv2_ch.mod mechanisms-modulation-ptr//kv4_ch.mod mechanisms-modulation-ptr//kv4_ch_ptr.mod mechanisms-modulation-ptr//na2_ch.mod mechanisms-modulation-ptr//na2_ch_ptr.mod mechanisms-modulation-ptr//na3n_lts.mod mechanisms-modulation-ptr//na3n_lts_ptr.mod mechanisms-modulation-ptr//na_ch.mod mechanisms-modulation-ptr//na_ch_ptr.mod mechanisms-modulation-ptr//naf_fs.mod mechanisms-modulation-ptr//naf_fs_ptr.mod mechanisms-modulation-ptr//naf_lts.mod mechanisms-modulation-ptr//naf_lts_ptr.mod mechanisms-modulation-ptr//naf_ms.mod mechanisms-modulation-ptr//naf_ms_ptr.mod mechanisms-modulation-ptr//NO.mod mechanisms-modulation-ptr//par_ggap.mod mechanisms-modulation-ptr//sk_ch.mod mechanisms-modulation-ptr//sk_fs.mod mechanisms-modulation-ptr//sk_ms.mod mechanisms-modulation-ptr//tmgabaa.mod mechanisms-modulation-ptr//tmgabaa_ptr.mod mechanisms-modulation-ptr//tmglut.mod mechanisms-modulation-ptr//tmglut_ptr.mod mechanisms-modulation-ptr//vecevent.mod
# bk_ch.mod bk_fs.mod bk_ms.mod ca_ch.mod cadyn_fs.mod cadyn_ms.mod cal12_ms.mod cal12_ms_ptr.mod cal13_ms.mod cal13_ms_ptr.mod cal_ch.mod cal_ch_ptr.mod caldyn_ms.mod can_fs.mod can_ms.mod can_ms_ptr.mod cap_ch.mod cap_ch_ptr.mod caq_fs.mod caq_ms.mod car_fs.mod car_ms.mod car_ms_ptr.mod cat32_ms.mod cat33_ms.mod concACh.mod concDA.mod hcn12_ch.mod hcn12_ch_ptr.mod hd_lts.mod hd_lts_ptr.mod im_lts.mod im_lts_ptr.mod Im_ms.mod Im_ms_ptr.mod it_lts.mod it_lts_ptr.mod kaf_fs.mod kaf_fs_ptr.mod kaf_lts.mod kaf_lts_ptr.mod kaf_ms.mod kaf_ms_ptr.mod kas_fs.mod kas_fs_ptr.mod kas_ms.mod kas_ms_ptr.mod kcnq_ch.mod kdb_lts.mod kdrbca1_lts.mod kdr_fs.mod kdr_lts.mod kdr_lts_ptr.mod kdr_ms.mod kir23_ch.mod kir23_ch_ptr.mod kir23_lts.mod kir23_lts_ptr.mod kir2_ch.mod kir2_ch_ptr.mod kir_fs.mod kir_fs_ptr.mod kir_ms.mod kir_ms_ptr.mod kv2_ch.mod kv4_ch.mod kv4_ch_ptr.mod na2_ch.mod na2_ch_ptr.mod na3n_lts.mod na3n_lts_ptr.mod na_ch.mod na_ch_ptr.mod naf_fs.mod naf_fs_ptr.mod naf_lts.mod naf_lts_ptr.mod naf_ms.mod naf_ms_ptr.mod NO.mod par_ggap.mod sk_ch.mod sk_fs.mod sk_ms.mod tmgabaa.mod tmgabaa_ptr.mod tmglut.mod tmglut_ptr.mod vecevent.mod
# "/usr/local/nrn/x86_64/bin/nocmodl" bk_ch
# "/usr/local/nrn/x86_64/bin/nocmodl" bk_fs
# "/usr/local/nrn/x86_64/bin/nocmodl" bk_ms
# "/usr/local/nrn/x86_64/bin/nocmodl" ca_ch
# Translating bk_ch.mod into bk_ch.c
# Translating bk_fs.mod into bk_fs.c
# Translating bk_ms.mod into bk_ms.c
# Notice: Assignment to the GLOBAL variable, "htau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "hinf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "mtau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "minf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "zinf", is not thread safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o bk_ch.lo bk_ch.c
# Thread Safe
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o bk_fs.lo bk_fs.c
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o bk_ms.lo bk_ms.c
# Translating ca_ch.mod into ca_ch.c
# Notice: Assignment to the GLOBAL variable, "vol", is not thread safe
# Warning: Default 1 of PARAMETER diam will be ignored and set by NEURON.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o ca_ch.lo ca_ch.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c bk_fs.c  -fPIC -DPIC -o .libs/bk_fs.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c bk_ch.c  -fPIC -DPIC -o .libs/bk_ch.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c ca_ch.c  -fPIC -DPIC -o .libs/ca_ch.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c bk_ms.c  -fPIC -DPIC -o .libs/bk_ms.o
# "/usr/local/nrn/x86_64/bin/nocmodl" cadyn_fs
# Translating cadyn_fs.mod into cadyn_fs.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cadyn_fs.lo cadyn_fs.c
# "/usr/local/nrn/x86_64/bin/nocmodl" cadyn_ms
# Translating cadyn_ms.mod into cadyn_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cadyn_ms.lo cadyn_ms.c
# "/usr/local/nrn/x86_64/bin/nocmodl" cal12_ms
# Translating cal12_ms.mod into cal12_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cal12_ms.lo cal12_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cadyn_fs.c  -fPIC -DPIC -o .libs/cadyn_fs.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cal12_ms.c  -fPIC -DPIC -o .libs/cal12_ms.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cadyn_ms.c  -fPIC -DPIC -o .libs/cadyn_ms.o
# "/usr/local/nrn/x86_64/bin/nocmodl" cal12_ms_ptr
# Translating cal12_ms_ptr.mod into cal12_ms_ptr.c
# Notice: Use of POINTER is not thread safe.
# Notice: Use of POINTER is not thread safe.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cal12_ms_ptr.lo cal12_ms_ptr.c
# "/usr/local/nrn/x86_64/bin/nocmodl" cal13_ms
# Translating cal13_ms.mod into cal13_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cal13_ms.lo cal13_ms.c
# "/usr/local/nrn/x86_64/bin/nocmodl" cal13_ms_ptr
# Translating cal13_ms_ptr.mod into cal13_ms_ptr.c
# Notice: Use of POINTER is not thread safe.
# Notice: Use of POINTER is not thread safe.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cal13_ms_ptr.lo cal13_ms_ptr.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cal12_ms_ptr.c  -fPIC -DPIC -o .libs/cal12_ms_ptr.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cal13_ms.c  -fPIC -DPIC -o .libs/cal13_ms.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cal13_ms_ptr.c  -fPIC -DPIC -o .libs/cal13_ms_ptr.o
# "/usr/local/nrn/x86_64/bin/nocmodl" cal_ch
# Translating cal_ch.mod into cal_ch.c
# Notice: Assignment to the GLOBAL variable, "minf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "tau", is not thread safe
# Warning: Default 6.3 of PARAMETER celsius will be ignored and set by NEURON.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cal_ch.lo cal_ch.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cal_ch.c  -fPIC -DPIC -o .libs/cal_ch.o
# "/usr/local/nrn/x86_64/bin/nocmodl" cal_ch_ptr
# Translating cal_ch_ptr.mod into cal_ch_ptr.c
# Notice: Use of POINTER is not thread safe.
# Notice: Assignment to the GLOBAL variable, "minf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "tau", is not thread safe
# Warning: Default 6.3 of PARAMETER celsius will be ignored and set by NEURON.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cal_ch_ptr.lo cal_ch_ptr.c
# "/usr/local/nrn/x86_64/bin/nocmodl" caldyn_ms
# Translating caldyn_ms.mod into caldyn_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o caldyn_ms.lo caldyn_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cal_ch_ptr.c  -fPIC -DPIC -o .libs/cal_ch_ptr.o
# "/usr/local/nrn/x86_64/bin/nocmodl" can_fs
# Translating can_fs.mod into can_fs.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o can_fs.lo can_fs.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c caldyn_ms.c  -fPIC -DPIC -o .libs/caldyn_ms.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c can_fs.c  -fPIC -DPIC -o .libs/can_fs.o
# "/usr/local/nrn/x86_64/bin/nocmodl" can_ms
# Translating can_ms.mod into can_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o can_ms.lo can_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c can_ms.c  -fPIC -DPIC -o .libs/can_ms.o
# "/usr/local/nrn/x86_64/bin/nocmodl" can_ms_ptr
# Translating can_ms_ptr.mod into can_ms_ptr.c
# Notice: Use of POINTER is not thread safe.
# Notice: Use of POINTER is not thread safe.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o can_ms_ptr.lo can_ms_ptr.c
# "/usr/local/nrn/x86_64/bin/nocmodl" cap_ch
# Translating cap_ch.mod into cap_ch.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c can_ms_ptr.c  -fPIC -DPIC -o .libs/can_ms_ptr.o
# Notice: Assignment to the GLOBAL variable, "mtau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "minf", is not thread safe
# Warning: Default 35 of PARAMETER celsius will be ignored and set by NEURON.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cap_ch.lo cap_ch.c
# "/usr/local/nrn/x86_64/bin/nocmodl" cap_ch_ptr
# Translating cap_ch_ptr.mod into cap_ch_ptr.c
# Notice: Use of POINTER is not thread safe.
# Notice: Use of POINTER is not thread safe.
# Notice: Assignment to the GLOBAL variable, "mtau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "minf", is not thread safe
# Warning: Default 35 of PARAMETER celsius will be ignored and set by NEURON.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cap_ch_ptr.lo cap_ch_ptr.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cap_ch_ptr.c  -fPIC -DPIC -o .libs/cap_ch_ptr.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cap_ch.c  -fPIC -DPIC -o .libs/cap_ch.o
# "/usr/local/nrn/x86_64/bin/nocmodl" caq_fs
# Translating caq_fs.mod into caq_fs.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o caq_fs.lo caq_fs.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c caq_fs.c  -fPIC -DPIC -o .libs/caq_fs.o
# "/usr/local/nrn/x86_64/bin/nocmodl" caq_ms
# Translating caq_ms.mod into caq_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o caq_ms.lo caq_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c caq_ms.c  -fPIC -DPIC -o .libs/caq_ms.o
# "/usr/local/nrn/x86_64/bin/nocmodl" car_fs
# Translating car_fs.mod into car_fs.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o car_fs.lo car_fs.c
# "/usr/local/nrn/x86_64/bin/nocmodl" car_ms
# Translating car_ms.mod into car_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o car_ms.lo car_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c car_fs.c  -fPIC -DPIC -o .libs/car_fs.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c car_ms.c  -fPIC -DPIC -o .libs/car_ms.o
# "/usr/local/nrn/x86_64/bin/nocmodl" car_ms_ptr
# Translating car_ms_ptr.mod into car_ms_ptr.c
# Notice: Use of POINTER is not thread safe.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o car_ms_ptr.lo car_ms_ptr.c
# "/usr/local/nrn/x86_64/bin/nocmodl" cat32_ms
# Translating cat32_ms.mod into cat32_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cat32_ms.lo cat32_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c car_ms_ptr.c  -fPIC -DPIC -o .libs/car_ms_ptr.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cat32_ms.c  -fPIC -DPIC -o .libs/cat32_ms.o
# "/usr/local/nrn/x86_64/bin/nocmodl" cat33_ms
# Translating cat33_ms.mod into cat33_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cat33_ms.lo cat33_ms.c
# "/usr/local/nrn/x86_64/bin/nocmodl" concACh
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cat33_ms.c  -fPIC -DPIC -o .libs/cat33_ms.o
# Translating concACh.mod into concACh.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o concACh.lo concACh.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c concACh.c  -fPIC -DPIC -o .libs/concACh.o
# "/usr/local/nrn/x86_64/bin/nocmodl" concDA
# Translating concDA.mod into concDA.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o concDA.lo concDA.c
# "/usr/local/nrn/x86_64/bin/nocmodl" hcn12_ch
# Translating hcn12_ch.mod into hcn12_ch.c
# NEURON's CVode method ignores conservation
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o hcn12_ch.lo hcn12_ch.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c concDA.c  -fPIC -DPIC -o .libs/concDA.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c hcn12_ch.c  -fPIC -DPIC -o .libs/hcn12_ch.o
# "/usr/local/nrn/x86_64/bin/nocmodl" hcn12_ch_ptr
# Translating hcn12_ch_ptr.mod into hcn12_ch_ptr.c
# Notice: Use of POINTER is not thread safe.
# NEURON's CVode method ignores conservation
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o hcn12_ch_ptr.lo hcn12_ch_ptr.c
# "/usr/local/nrn/x86_64/bin/nocmodl" hd_lts
# Translating hd_lts.mod into hd_lts.c
# Notice: Assignment to the GLOBAL variable, "linf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "taul", is not thread safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o hd_lts.lo hd_lts.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c hcn12_ch_ptr.c  -fPIC -DPIC -o .libs/hcn12_ch_ptr.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c hd_lts.c  -fPIC -DPIC -o .libs/hd_lts.o
# "/usr/local/nrn/x86_64/bin/nocmodl" hd_lts_ptr
# Translating hd_lts_ptr.mod into hd_lts_ptr.c
# Notice: Use of POINTER is not thread safe.
# Notice: Assignment to the GLOBAL variable, "linf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "taul", is not thread safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o hd_lts_ptr.lo hd_lts_ptr.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c hd_lts_ptr.c  -fPIC -DPIC -o .libs/hd_lts_ptr.o
# "/usr/local/nrn/x86_64/bin/nocmodl" im_lts
# Translating im_lts.mod into im_lts.c
# Warning: Default 36 of PARAMETER celsius will be ignored and set by NEURON.
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o im_lts.lo im_lts.c
# "/usr/local/nrn/x86_64/bin/nocmodl" im_lts_ptr
# Translating im_lts_ptr.mod into im_lts_ptr.c
# Notice: Use of POINTER is not thread safe.
# Notice: Use of POINTER is not thread safe.
# Warning: Default 36 of PARAMETER celsius will be ignored and set by NEURON.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o im_lts_ptr.lo im_lts_ptr.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c im_lts.c  -fPIC -DPIC -o .libs/im_lts.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c im_lts_ptr.c  -fPIC -DPIC -o .libs/im_lts_ptr.o
# "/usr/local/nrn/x86_64/bin/nocmodl" Im_ms
# Translating Im_ms.mod into Im_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o Im_ms.lo Im_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c Im_ms.c  -fPIC -DPIC -o .libs/Im_ms.o
# "/usr/local/nrn/x86_64/bin/nocmodl" Im_ms_ptr
# Translating Im_ms_ptr.mod into Im_ms_ptr.c
# Notice: Use of POINTER is not thread safe.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o Im_ms_ptr.lo Im_ms_ptr.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c Im_ms_ptr.c  -fPIC -DPIC -o .libs/Im_ms_ptr.o
# "/usr/local/nrn/x86_64/bin/nocmodl" it_lts
# Translating it_lts.mod into it_lts.c
# Warning: Default 36 of PARAMETER celsius will be ignored and set by NEURON.
# Warning: Default 2 of PARAMETER cao will be ignored and set by NEURON.
# Warning: Default 0.00024 of PARAMETER cai will be ignored and set by NEURON.
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o it_lts.lo it_lts.c
# "/usr/local/nrn/x86_64/bin/nocmodl" it_lts_ptr
# Translating it_lts_ptr.mod into it_lts_ptr.c
# Notice: Use of POINTER is not thread safe.
# Warning: Default 36 of PARAMETER celsius will be ignored and set by NEURON.
# Warning: Default 2 of PARAMETER cao will be ignored and set by NEURON.
# Warning: Default 0.00024 of PARAMETER cai will be ignored and set by NEURON.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o it_lts_ptr.lo it_lts_ptr.c
# "/usr/local/nrn/x86_64/bin/nocmodl" kaf_fs
# Translating kaf_fs.mod into kaf_fs.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kaf_fs.lo kaf_fs.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c it_lts.c  -fPIC -DPIC -o .libs/it_lts.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c it_lts_ptr.c  -fPIC -DPIC -o .libs/it_lts_ptr.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kaf_fs.c  -fPIC -DPIC -o .libs/kaf_fs.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kaf_fs_ptr
# Translating kaf_fs_ptr.mod into kaf_fs_ptr.c
# Notice: Use of POINTER is not thread safe.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kaf_fs_ptr.lo kaf_fs_ptr.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kaf_fs_ptr.c  -fPIC -DPIC -o .libs/kaf_fs_ptr.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kaf_lts
# Translating kaf_lts.mod into kaf_lts.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kaf_lts.lo kaf_lts.c
# "/usr/local/nrn/x86_64/bin/nocmodl" kaf_lts_ptr
# Translating kaf_lts_ptr.mod into kaf_lts_ptr.c
# Notice: Use of POINTER is not thread safe.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kaf_lts_ptr.lo kaf_lts_ptr.c
# "/usr/local/nrn/x86_64/bin/nocmodl" kaf_ms
# Translating kaf_ms.mod into kaf_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kaf_ms.lo kaf_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kaf_lts.c  -fPIC -DPIC -o .libs/kaf_lts.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kaf_ms.c  -fPIC -DPIC -o .libs/kaf_ms.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kaf_ms_ptr
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kaf_lts_ptr.c  -fPIC -DPIC -o .libs/kaf_lts_ptr.o
# Translating kaf_ms_ptr.mod into kaf_ms_ptr.c
# Notice: Use of POINTER is not thread safe.
# Notice: Use of POINTER is not thread safe.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kaf_ms_ptr.lo kaf_ms_ptr.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kaf_ms_ptr.c  -fPIC -DPIC -o .libs/kaf_ms_ptr.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kas_fs
# Translating kas_fs.mod into kas_fs.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kas_fs.lo kas_fs.c
# "/usr/local/nrn/x86_64/bin/nocmodl" kas_fs_ptr
# Translating kas_fs_ptr.mod into kas_fs_ptr.c
# Notice: Use of POINTER is not thread safe.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kas_fs_ptr.lo kas_fs_ptr.c
# "/usr/local/nrn/x86_64/bin/nocmodl" kas_ms
# Translating kas_ms.mod into kas_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kas_ms.lo kas_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kas_fs.c  -fPIC -DPIC -o .libs/kas_fs.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kas_ms_ptr
# Translating kas_ms_ptr.mod into kas_ms_ptr.c
# Notice: Use of POINTER is not thread safe.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kas_ms_ptr.lo kas_ms_ptr.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kas_fs_ptr.c  -fPIC -DPIC -o .libs/kas_fs_ptr.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kas_ms.c  -fPIC -DPIC -o .libs/kas_ms.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kas_ms_ptr.c  -fPIC -DPIC -o .libs/kas_ms_ptr.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kcnq_ch
# Translating kcnq_ch.mod into kcnq_ch.c
# NEURON's CVode method ignores conservation
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kcnq_ch.lo kcnq_ch.c
# "/usr/local/nrn/x86_64/bin/nocmodl" kdb_lts
# "/usr/local/nrn/x86_64/bin/nocmodl" kdrbca1_lts
# Translating kdb_lts.mod into kdb_lts.c
# Translating kdrbca1_lts.mod into kdrbca1_lts.c
# Notice: Assignment to the GLOBAL variable, "ninf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "taun", is not thread safe
# Notice: Assignment to the GLOBAL variable, "ninf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "taun", is not thread safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kdb_lts.lo kdb_lts.c
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kdrbca1_lts.lo kdrbca1_lts.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kcnq_ch.c  -fPIC -DPIC -o .libs/kcnq_ch.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kdr_fs
# Translating kdr_fs.mod into kdr_fs.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kdr_fs.lo kdr_fs.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kdb_lts.c  -fPIC -DPIC -o .libs/kdb_lts.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kdrbca1_lts.c  -fPIC -DPIC -o .libs/kdrbca1_lts.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kdr_fs.c  -fPIC -DPIC -o .libs/kdr_fs.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kdr_lts
# Translating kdr_lts.mod into kdr_lts.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kdr_lts.lo kdr_lts.c
# "/usr/local/nrn/x86_64/bin/nocmodl" kdr_lts_ptr
# Translating kdr_lts_ptr.mod into kdr_lts_ptr.c
# Notice: Use of POINTER is not thread safe.
# "/usr/local/nrn/x86_64/bin/nocmodl" kdr_ms
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kdr_lts_ptr.lo kdr_lts_ptr.c
# Translating kdr_ms.mod into kdr_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kdr_ms.lo kdr_ms.c
# "/usr/local/nrn/x86_64/bin/nocmodl" kir23_ch
# Translating kir23_ch.mod into kir23_ch.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kir23_ch.lo kir23_ch.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kdr_lts.c  -fPIC -DPIC -o .libs/kdr_lts.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kdr_lts_ptr.c  -fPIC -DPIC -o .libs/kdr_lts_ptr.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kdr_ms.c  -fPIC -DPIC -o .libs/kdr_ms.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kir23_ch.c  -fPIC -DPIC -o .libs/kir23_ch.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kir23_ch_ptr
# Translating kir23_ch_ptr.mod into kir23_ch_ptr.c
# Notice: Use of POINTER is not thread safe.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kir23_ch_ptr.lo kir23_ch_ptr.c
# "/usr/local/nrn/x86_64/bin/nocmodl" kir23_lts
# Translating kir23_lts.mod into kir23_lts.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kir23_lts.lo kir23_lts.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kir23_ch_ptr.c  -fPIC -DPIC -o .libs/kir23_ch_ptr.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kir23_lts.c  -fPIC -DPIC -o .libs/kir23_lts.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kir23_lts_ptr
# Translating kir23_lts_ptr.mod into kir23_lts_ptr.c
# Notice: Use of POINTER is not thread safe.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kir23_lts_ptr.lo kir23_lts_ptr.c
# "/usr/local/nrn/x86_64/bin/nocmodl" kir2_ch
# Translating kir2_ch.mod into kir2_ch.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kir2_ch.lo kir2_ch.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kir23_lts_ptr.c  -fPIC -DPIC -o .libs/kir23_lts_ptr.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kir2_ch.c  -fPIC -DPIC -o .libs/kir2_ch.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kir2_ch_ptr
# "/usr/local/nrn/x86_64/bin/nocmodl" kir_fs
# Translating kir2_ch_ptr.mod into kir2_ch_ptr.c
# Notice: Use of POINTER is not thread safe.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kir2_ch_ptr.lo kir2_ch_ptr.c
# Translating kir_fs.mod into kir_fs.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kir_fs.lo kir_fs.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kir_fs.c  -fPIC -DPIC -o .libs/kir_fs.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kir2_ch_ptr.c  -fPIC -DPIC -o .libs/kir2_ch_ptr.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kir_fs_ptr
# Translating kir_fs_ptr.mod into kir_fs_ptr.c
# Notice: Use of POINTER is not thread safe.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kir_fs_ptr.lo kir_fs_ptr.c
# "/usr/local/nrn/x86_64/bin/nocmodl" kir_ms
# Translating kir_ms.mod into kir_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kir_ms.lo kir_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kir_fs_ptr.c  -fPIC -DPIC -o .libs/kir_fs_ptr.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kir_ms.c  -fPIC -DPIC -o .libs/kir_ms.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kir_ms_ptr
# Translating kir_ms_ptr.mod into kir_ms_ptr.c
# Notice: Use of POINTER is not thread safe.
# Notice: Use of POINTER is not thread safe.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kir_ms_ptr.lo kir_ms_ptr.c
# "/usr/local/nrn/x86_64/bin/nocmodl" kv2_ch
# Translating kv2_ch.mod into kv2_ch.c
# NEURON's CVode method ignores conservation
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kv2_ch.lo kv2_ch.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kv2_ch.c  -fPIC -DPIC -o .libs/kv2_ch.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kir_ms_ptr.c  -fPIC -DPIC -o .libs/kir_ms_ptr.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kv4_ch
# Translating kv4_ch.mod into kv4_ch.c
# NEURON's CVode method ignores conservation
# Notice: Assignment to the GLOBAL variable, "alpha", is not thread safe
# Notice: Assignment to the GLOBAL variable, "beta", is not thread safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kv4_ch.lo kv4_ch.c
# "/usr/local/nrn/x86_64/bin/nocmodl" kv4_ch_ptr
# Translating kv4_ch_ptr.mod into kv4_ch_ptr.c
# Notice: Use of POINTER is not thread safe.
# NEURON's CVode method ignores conservation
# Notice: Assignment to the GLOBAL variable, "alpha", is not thread safe
# Notice: Assignment to the GLOBAL variable, "beta", is not thread safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kv4_ch_ptr.lo kv4_ch_ptr.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kv4_ch.c  -fPIC -DPIC -o .libs/kv4_ch.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kv4_ch_ptr.c  -fPIC -DPIC -o .libs/kv4_ch_ptr.o
# "/usr/local/nrn/x86_64/bin/nocmodl" na2_ch
# Translating na2_ch.mod into na2_ch.c
# NEURON's CVode method ignores conservation
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o na2_ch.lo na2_ch.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c na2_ch.c  -fPIC -DPIC -o .libs/na2_ch.o
# "/usr/local/nrn/x86_64/bin/nocmodl" na2_ch_ptr
# Translating na2_ch_ptr.mod into na2_ch_ptr.c
# Notice: Use of POINTER is not thread safe.
# NEURON's CVode method ignores conservation
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o na2_ch_ptr.lo na2_ch_ptr.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c na2_ch_ptr.c  -fPIC -DPIC -o .libs/na2_ch_ptr.o
# "/usr/local/nrn/x86_64/bin/nocmodl" na3n_lts
# Translating na3n_lts.mod into na3n_lts.c
# Notice: Assignment to the GLOBAL variable, "htau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "hinf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "mtau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "minf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "sinf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "taus", is not thread safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o na3n_lts.lo na3n_lts.c
# "/usr/local/nrn/x86_64/bin/nocmodl" na3n_lts_ptr
# Translating na3n_lts_ptr.mod into na3n_lts_ptr.c
# Notice: Use of POINTER is not thread safe.
# Notice: Assignment to the GLOBAL variable, "htau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "hinf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "mtau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "minf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "sinf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "taus", is not thread safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o na3n_lts_ptr.lo na3n_lts_ptr.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c na3n_lts.c  -fPIC -DPIC -o .libs/na3n_lts.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c na3n_lts_ptr.c  -fPIC -DPIC -o .libs/na3n_lts_ptr.o
# "/usr/local/nrn/x86_64/bin/nocmodl" na_ch
# Translating na_ch.mod into na_ch.c
# NEURON's CVode method ignores conservation
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o na_ch.lo na_ch.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c na_ch.c  -fPIC -DPIC -o .libs/na_ch.o
# "/usr/local/nrn/x86_64/bin/nocmodl" na_ch_ptr
# Translating na_ch_ptr.mod into na_ch_ptr.c
# Notice: Use of POINTER is not thread safe.
# NEURON's CVode method ignores conservation
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o na_ch_ptr.lo na_ch_ptr.c
# "/usr/local/nrn/x86_64/bin/nocmodl" naf_fs
# Translating naf_fs.mod into naf_fs.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o naf_fs.lo naf_fs.c
# "/usr/local/nrn/x86_64/bin/nocmodl" naf_fs_ptr
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c na_ch_ptr.c  -fPIC -DPIC -o .libs/na_ch_ptr.o
# Translating naf_fs_ptr.mod into naf_fs_ptr.c
# Notice: Use of POINTER is not thread safe.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o naf_fs_ptr.lo naf_fs_ptr.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c naf_fs_ptr.c  -fPIC -DPIC -o .libs/naf_fs_ptr.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c naf_fs.c  -fPIC -DPIC -o .libs/naf_fs.o
# "/usr/local/nrn/x86_64/bin/nocmodl" naf_lts
# "/usr/local/nrn/x86_64/bin/nocmodl" naf_lts_ptr
# Translating naf_lts_ptr.mod into naf_lts_ptr.c
# Translating naf_lts.mod into naf_lts.c
# Notice: Use of POINTER is not thread safe.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o naf_lts_ptr.lo naf_lts_ptr.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o naf_lts.lo naf_lts.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c naf_lts.c  -fPIC -DPIC -o .libs/naf_lts.o
# "/usr/local/nrn/x86_64/bin/nocmodl" naf_ms
# Translating naf_ms.mod into naf_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o naf_ms.lo naf_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c naf_lts_ptr.c  -fPIC -DPIC -o .libs/naf_lts_ptr.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c naf_ms.c  -fPIC -DPIC -o .libs/naf_ms.o
# "/usr/local/nrn/x86_64/bin/nocmodl" naf_ms_ptr
# Translating naf_ms_ptr.mod into naf_ms_ptr.c
# Notice: Use of POINTER is not thread safe.
# Notice: Use of POINTER is not thread safe.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o naf_ms_ptr.lo naf_ms_ptr.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c naf_ms_ptr.c  -fPIC -DPIC -o .libs/naf_ms_ptr.o
# "/usr/local/nrn/x86_64/bin/nocmodl" NO
# Translating NO.mod into NO.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o NO.lo NO.c
# "/usr/local/nrn/x86_64/bin/nocmodl" par_ggap
# "/usr/local/nrn/x86_64/bin/nocmodl" sk_ch
# Translating par_ggap.mod into par_ggap.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o par_ggap.lo par_ggap.c
# Translating sk_ch.mod into sk_ch.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o sk_ch.lo sk_ch.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c NO.c  -fPIC -DPIC -o .libs/NO.o
# "/usr/local/nrn/x86_64/bin/nocmodl" sk_fs
# Translating sk_fs.mod into sk_fs.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o sk_fs.lo sk_fs.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c par_ggap.c  -fPIC -DPIC -o .libs/par_ggap.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c sk_ch.c  -fPIC -DPIC -o .libs/sk_ch.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c sk_fs.c  -fPIC -DPIC -o .libs/sk_fs.o
# "/usr/local/nrn/x86_64/bin/nocmodl" sk_ms
# Translating sk_ms.mod into sk_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o sk_ms.lo sk_ms.c
# "/usr/local/nrn/x86_64/bin/nocmodl" tmgabaa
# Translating tmgabaa.mod into tmgabaa.c
# Notice: VERBATIM blocks are not thread safe
# Notice: scop_random is not thread safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o tmgabaa.lo tmgabaa.c
# "/usr/local/nrn/x86_64/bin/nocmodl" tmgabaa_ptr
# Translating tmgabaa_ptr.mod into tmgabaa_ptr.c
# Notice: Use of POINTER is not thread safe.
# Notice: Use of POINTER is not thread safe.
# Notice: VERBATIM blocks are not thread safe
# Notice: scop_random is not thread safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o tmgabaa_ptr.lo tmgabaa_ptr.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c tmgabaa.c  -fPIC -DPIC -o .libs/tmgabaa.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c sk_ms.c  -fPIC -DPIC -o .libs/sk_ms.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c tmgabaa_ptr.c  -fPIC -DPIC -o .libs/tmgabaa_ptr.o
# "/usr/local/nrn/x86_64/bin/nocmodl" tmglut
# Translating tmglut.mod into tmglut.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o tmglut.lo tmglut.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c tmglut.c  -fPIC -DPIC -o .libs/tmglut.o
# "/usr/local/nrn/x86_64/bin/nocmodl" tmglut_ptr
# Translating tmglut_ptr.mod into tmglut_ptr.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o tmglut_ptr.lo tmglut_ptr.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c tmglut_ptr.c  -fPIC -DPIC -o .libs/tmglut_ptr.o
# "/usr/local/nrn/x86_64/bin/nocmodl" vecevent
# Translating vecevent.mod into vecevent.c
# Notice: ARTIFICIAL_CELL is a synonym for POINT_PROCESS which hints that it
# only affects and is affected by discrete events. As such it is not
# located in a section and is not associated with an integrator
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o vecevent.lo vecevent.c
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o mod_func.lo mod_func.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c vecevent.c  -fPIC -DPIC -o .libs/vecevent.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c mod_func.c  -fPIC -DPIC -o .libs/mod_func.o
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=link mpicc -module  -g -O2    -o libnrnmech.la -rpath "/usr/local/nrn/x86_64/lib"  bk_ch.lo bk_fs.lo bk_ms.lo ca_ch.lo cadyn_fs.lo cadyn_ms.lo cal12_ms.lo cal12_ms_ptr.lo cal13_ms.lo cal13_ms_ptr.lo cal_ch.lo cal_ch_ptr.lo caldyn_ms.lo can_fs.lo can_ms.lo can_ms_ptr.lo cap_ch.lo cap_ch_ptr.lo caq_fs.lo caq_ms.lo car_fs.lo car_ms.lo car_ms_ptr.lo cat32_ms.lo cat33_ms.lo concACh.lo concDA.lo hcn12_ch.lo hcn12_ch_ptr.lo hd_lts.lo hd_lts_ptr.lo im_lts.lo im_lts_ptr.lo Im_ms.lo Im_ms_ptr.lo it_lts.lo it_lts_ptr.lo kaf_fs.lo kaf_fs_ptr.lo kaf_lts.lo kaf_lts_ptr.lo kaf_ms.lo kaf_ms_ptr.lo kas_fs.lo kas_fs_ptr.lo kas_ms.lo kas_ms_ptr.lo kcnq_ch.lo kdb_lts.lo kdrbca1_lts.lo kdr_fs.lo kdr_lts.lo kdr_lts_ptr.lo kdr_ms.lo kir23_ch.lo kir23_ch_ptr.lo kir23_lts.lo kir23_lts_ptr.lo kir2_ch.lo kir2_ch_ptr.lo kir_fs.lo kir_fs_ptr.lo kir_ms.lo kir_ms_ptr.lo kv2_ch.lo kv4_ch.lo kv4_ch_ptr.lo na2_ch.lo na2_ch_ptr.lo na3n_lts.lo na3n_lts_ptr.lo na_ch.lo na_ch_ptr.lo naf_fs.lo naf_fs_ptr.lo naf_lts.lo naf_lts_ptr.lo naf_ms.lo naf_ms_ptr.lo NO.lo par_ggap.lo sk_ch.lo sk_fs.lo sk_ms.lo tmgabaa.lo tmgabaa_ptr.lo tmglut.lo tmglut_ptr.lo vecevent.lo mod_func.lo  -L"/usr/local/nrn/x86_64/lib" -lnrnoc -loc -lmemacs -lnrnmpi -lscopmath -lsparse13 -lreadline -lncurses -ltinfo -L"/usr/local/nrn/x86_64/lib" -lnrniv -livoc -lneuron_gnu -lmeschach -lsundials       -lm -ldl
# libtool: link: mpicc -shared  -fPIC -DPIC  .libs/bk_ch.o .libs/bk_fs.o .libs/bk_ms.o .libs/ca_ch.o .libs/cadyn_fs.o .libs/cadyn_ms.o .libs/cal12_ms.o .libs/cal12_ms_ptr.o .libs/cal13_ms.o .libs/cal13_ms_ptr.o .libs/cal_ch.o .libs/cal_ch_ptr.o .libs/caldyn_ms.o .libs/can_fs.o .libs/can_ms.o .libs/can_ms_ptr.o .libs/cap_ch.o .libs/cap_ch_ptr.o .libs/caq_fs.o .libs/caq_ms.o .libs/car_fs.o .libs/car_ms.o .libs/car_ms_ptr.o .libs/cat32_ms.o .libs/cat33_ms.o .libs/concACh.o .libs/concDA.o .libs/hcn12_ch.o .libs/hcn12_ch_ptr.o .libs/hd_lts.o .libs/hd_lts_ptr.o .libs/im_lts.o .libs/im_lts_ptr.o .libs/Im_ms.o .libs/Im_ms_ptr.o .libs/it_lts.o .libs/it_lts_ptr.o .libs/kaf_fs.o .libs/kaf_fs_ptr.o .libs/kaf_lts.o .libs/kaf_lts_ptr.o .libs/kaf_ms.o .libs/kaf_ms_ptr.o .libs/kas_fs.o .libs/kas_fs_ptr.o .libs/kas_ms.o .libs/kas_ms_ptr.o .libs/kcnq_ch.o .libs/kdb_lts.o .libs/kdrbca1_lts.o .libs/kdr_fs.o .libs/kdr_lts.o .libs/kdr_lts_ptr.o .libs/kdr_ms.o .libs/kir23_ch.o .libs/kir23_ch_ptr.o .libs/kir23_lts.o .libs/kir23_lts_ptr.o .libs/kir2_ch.o .libs/kir2_ch_ptr.o .libs/kir_fs.o .libs/kir_fs_ptr.o .libs/kir_ms.o .libs/kir_ms_ptr.o .libs/kv2_ch.o .libs/kv4_ch.o .libs/kv4_ch_ptr.o .libs/na2_ch.o .libs/na2_ch_ptr.o .libs/na3n_lts.o .libs/na3n_lts_ptr.o .libs/na_ch.o .libs/na_ch_ptr.o .libs/naf_fs.o .libs/naf_fs_ptr.o .libs/naf_lts.o .libs/naf_lts_ptr.o .libs/naf_ms.o .libs/naf_ms_ptr.o .libs/NO.o .libs/par_ggap.o .libs/sk_ch.o .libs/sk_fs.o .libs/sk_ms.o .libs/tmgabaa.o .libs/tmgabaa_ptr.o .libs/tmglut.o .libs/tmglut_ptr.o .libs/vecevent.o .libs/mod_func.o   -Wl,-rpath -Wl,/usr/local/nrn/x86_64/lib -Wl,-rpath -Wl,/usr/local/nrn/x86_64/lib -L/usr/local/nrn/x86_64/lib /usr/local/nrn/x86_64/lib/libnrnoc.so /usr/local/nrn/x86_64/lib/liboc.so -lX11 /usr/local/nrn/x86_64/lib/libmemacs.so /usr/local/nrn/x86_64/lib/libnrnmpi.so /usr/local/nrn/x86_64/lib/libscopmath.so /usr/local/nrn/x86_64/lib/libsparse13.so /usr/local/nrn/x86_64/lib/libreadline.so -lncurses -ltinfo /usr/local/nrn/x86_64/lib/libnrniv.so /usr/local/nrn/x86_64/lib/libivoc.so /usr/local/nrn/x86_64/lib/libneuron_gnu.so /usr/local/nrn/x86_64/lib/libmeschach.so /usr/local/nrn/x86_64/lib/libsundials.so -lm -ldl  -g -O2   -Wl,-soname -Wl,libnrnmech.so.0 -o .libs/libnrnmech.so.0.0.0
# libtool: link: (cd ".libs" && rm -f "libnrnmech.so.0" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so.0")
# libtool: link: (cd ".libs" && rm -f "libnrnmech.so" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so")
# libtool: link: ( cd ".libs" && rm -f "libnrnmech.la" && ln -s "../libnrnmech.la" "libnrnmech.la" )
# Successfully created x86_64/special

# %% [markdown]
# Restart the kernel (if the assembly and generation of input and simulation are in different notebooks - THIS STEP IS NOT NEEDED)

# %%
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
restartkernel()
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
from snudda.input import SnuddaInput
import os

os.environ["SNUDDA_DATA"] = "data"

network_path = "dopamine-acetylcholine-adaptive-trial-network"

si = SnuddaInput(network_path=network_path, 
                 input_config_file=os.path.join("data","external_input","external-input-trial.json"),
                 verbose=False)
si.generate()
# Out:
# Loading 14 neurons with 11153 synapses and 0 gap junctions
# Writing spikes to dopamine-acetylcholine-adaptive-trial-network/input-spikes.hdf5

# %% [markdown]
# We then simulate the dopamine-acetylcholine and control case using Snudda

# %%
import os

os.environ["SNUDDA_DATA"] = "data"

# %%
# !snudda simulate dopamine-acetylcholine-adaptive-trial-network --time 3.0 --outputFile "dopamine-acetylcholine-adaptive-trial-network/simulation/network-voltage-DA-ACh-trial.hdf5" --neuromodulation "data/modulation/DA-ACh.json"
# Out:
# Using input file dopamine-acetylcholine-adaptive-trial-network/input-spikes.hdf5
# NEURON mechanisms already compiled, make sure you have the correct version of NEURON modules.
# If you delete x86_64 directory (or nrnmech.dll) then you will force a recompilation of the modules.
# args: Namespace(action='simulate', disable_gj=False, exportCoreNeuron=False, input_file=None, mech_dir=None, network_file=None, neuromodulation='data/modulation/DA-ACh.json', output_file='dopamine-acetylcholine-adaptive-trial-network/simulation/network-voltage-DA-ACh-trial.hdf5', path='dopamine-acetylcholine-adaptive-trial-network', profile=False, randomseed=None, record_all=None, record_volt=True, time=3.0, verbose=False)
# Loading 14 neurons with 11153 synapses and 0 gap junctions
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/bluepyopt/ephys/simulators.py:89: UserWarning: Unable to find Neuron hoc shared library in /usr/local/nrn/lib/python/neuron, not disabling banner
#   'not disabling banner' % nrnpy_path)
# !!! Found 1146 synapses on dSPN_1 (9)  that are further than 20 mum away  (out of 1146 synapses) Max found was 31 mum from expected location. morphology: /home/jofrony/Documents/Repositories/BasalGangliaPublications/Neuromodulation-software/examples/data/neurons/striatum/dspn/str-dspn-e150917_c10_D1-mWT-P270-20-v20210212/WT-P270-20-15ak-cor-res3.swc
#  Check that soma is centered at (0,0,0). Also check that the first dendritic compartment of each dendrite is not too far away from the soma, then NEURON  adds an extra connecting compartment which messes up section IDs.
# !!! Found 1145 synapses on dSPN_1 (13)  that are further than 20 mum away  (out of 1147 synapses) Max found was 31 mum from expected location. morphology: /home/jofrony/Documents/Repositories/BasalGangliaPublications/Neuromodulation-software/examples/data/neurons/striatum/dspn/str-dspn-e150917_c10_D1-mWT-P270-20-v20210212/WT-P270-20-15ak-cor-res3.swc
#  Check that soma is centered at (0,0,0). Also check that the first dendritic compartment of each dendrite is not too far away from the soma, then NEURON  adds an extra connecting compartment which messes up section IDs.
# !!! Found 1146 synapses on dSPN_1 (9)  that are further than 20 mum away  (out of 1146 synapses) Max found was 31 mum from expected location. morphology: /home/jofrony/Documents/Repositories/BasalGangliaPublications/Neuromodulation-software/examples/data/neurons/striatum/dspn/str-dspn-e150917_c10_D1-mWT-P270-20-v20210212/WT-P270-20-15ak-cor-res3.swc
#  Check that soma is centered at (0,0,0). Also check that the first dendritic compartment of each dendrite is not too far away from the soma, then NEURON  adds an extra connecting compartment which messes up section IDs.
# !!! Found 1145 synapses on dSPN_1 (13)  that are further than 20 mum away  (out of 1147 synapses) Max found was 31 mum from expected location. morphology: /home/jofrony/Documents/Repositories/BasalGangliaPublications/Neuromodulation-software/examples/data/neurons/striatum/dspn/str-dspn-e150917_c10_D1-mWT-P270-20-v20210212/WT-P270-20-15ak-cor-res3.swc
#  Check that soma is centered at (0,0,0). Also check that the first dendritic compartment of each dendrite is not too far away from the soma, then NEURON  adds an extra connecting compartment which messes up section IDs.
# Running simulation for 3000.0 ms.
# Running simulation for 3.0 s
# Running Neuron simulator 3000 ms, with dt=0.025
# 1% done. Elapsed: 6.2 s, estimated time left: 609.8 s
# exp(790.194) out of range, returning exp(700)
# exp(874.716) out of range, returning exp(700)
# exp(953.952) out of range, returning exp(700)
# exp(777.744) out of range, returning exp(700)
# No more errno warnings during this execution
# 17% done. Elapsed: 109.8 s, estimated time left: 535.9 s
# 32% done. Elapsed: 210.6 s, estimated time left: 447.6 s
# 49% done. Elapsed: 313.0 s, estimated time left: 325.8 s
# 67% done. Elapsed: 415.7 s, estimated time left: 204.7 s
# 85% done. Elapsed: 516.8 s, estimated time left: 91.2 s
# Neuron simulation finished
# Simulation run time: 601.1 s
# Simulation done, saving output
# Writing network output to dopamine-acetylcholine-adaptive-trial-network/simulation/network-voltage-DA-ACh-trial.hdf5
# Using sample dt = 0.0005 (sample step size 20)
# Worker 1/1 writing data to dopamine-acetylcholine-adaptive-trial-network/simulation/network-voltage-DA-ACh-trial.hdf5
# Program run time: 612.4s

# %%
# !snudda simulate dopamine-acetylcholine-adaptive-trial-network --time 3.0 --outputFile 'dopamine-acetylcholine-adaptive-trial-network/simulation/network-voltage-DA-ACh-trial-control.hdf5' --neuromodulation "data/modulation/DA-ACh-control.json"
# Out:
# Using input file dopamine-acetylcholine-adaptive-trial-network/input-spikes.hdf5
# NEURON mechanisms already compiled, make sure you have the correct version of NEURON modules.
# If you delete x86_64 directory (or nrnmech.dll) then you will force a recompilation of the modules.
# args: Namespace(action='simulate', disable_gj=False, exportCoreNeuron=False, input_file=None, mech_dir=None, network_file=None, neuromodulation='data/modulation/DA-ACh-control.json', output_file='dopamine-acetylcholine-adaptive-trial-network/simulation/network-voltage-DA-ACh-trial-control.hdf5', path='dopamine-acetylcholine-adaptive-trial-network', profile=False, randomseed=None, record_all=None, record_volt=True, time=3.0, verbose=False)
# Loading 14 neurons with 11153 synapses and 0 gap junctions
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/bluepyopt/ephys/simulators.py:89: UserWarning: Unable to find Neuron hoc shared library in /usr/local/nrn/lib/python/neuron, not disabling banner
#   'not disabling banner' % nrnpy_path)
# !!! Found 1146 synapses on dSPN_1 (9)  that are further than 20 mum away  (out of 1146 synapses) Max found was 31 mum from expected location. morphology: /home/jofrony/Documents/Repositories/BasalGangliaPublications/Neuromodulation-software/examples/data/neurons/striatum/dspn/str-dspn-e150917_c10_D1-mWT-P270-20-v20210212/WT-P270-20-15ak-cor-res3.swc
#  Check that soma is centered at (0,0,0). Also check that the first dendritic compartment of each dendrite is not too far away from the soma, then NEURON  adds an extra connecting compartment which messes up section IDs.
# !!! Found 1145 synapses on dSPN_1 (13)  that are further than 20 mum away  (out of 1147 synapses) Max found was 31 mum from expected location. morphology: /home/jofrony/Documents/Repositories/BasalGangliaPublications/Neuromodulation-software/examples/data/neurons/striatum/dspn/str-dspn-e150917_c10_D1-mWT-P270-20-v20210212/WT-P270-20-15ak-cor-res3.swc
#  Check that soma is centered at (0,0,0). Also check that the first dendritic compartment of each dendrite is not too far away from the soma, then NEURON  adds an extra connecting compartment which messes up section IDs.
# !!! Found 1146 synapses on dSPN_1 (9)  that are further than 20 mum away  (out of 1146 synapses) Max found was 31 mum from expected location. morphology: /home/jofrony/Documents/Repositories/BasalGangliaPublications/Neuromodulation-software/examples/data/neurons/striatum/dspn/str-dspn-e150917_c10_D1-mWT-P270-20-v20210212/WT-P270-20-15ak-cor-res3.swc
#  Check that soma is centered at (0,0,0). Also check that the first dendritic compartment of each dendrite is not too far away from the soma, then NEURON  adds an extra connecting compartment which messes up section IDs.
# !!! Found 1145 synapses on dSPN_1 (13)  that are further than 20 mum away  (out of 1147 synapses) Max found was 31 mum from expected location. morphology: /home/jofrony/Documents/Repositories/BasalGangliaPublications/Neuromodulation-software/examples/data/neurons/striatum/dspn/str-dspn-e150917_c10_D1-mWT-P270-20-v20210212/WT-P270-20-15ak-cor-res3.swc
#  Check that soma is centered at (0,0,0). Also check that the first dendritic compartment of each dendrite is not too far away from the soma, then NEURON  adds an extra connecting compartment which messes up section IDs.
# Running simulation for 3000.0 ms.
# Running simulation for 3.0 s
# Running Neuron simulator 3000 ms, with dt=0.025
# 1% done. Elapsed: 6.0 s, estimated time left: 590.3 s
# 18% done. Elapsed: 107.5 s, estimated time left: 489.6 s
# 35% done. Elapsed: 209.9 s, estimated time left: 389.8 s
# 52% done. Elapsed: 312.5 s, estimated time left: 288.5 s
# 69% done. Elapsed: 415.1 s, estimated time left: 186.5 s
# 86% done. Elapsed: 517.7 s, estimated time left: 84.3 s
# Neuron simulation finished
# Simulation run time: 602.6 s
# Simulation done, saving output
# Writing network output to dopamine-acetylcholine-adaptive-trial-network/simulation/network-voltage-DA-ACh-trial-control.hdf5
# Using sample dt = 0.0005 (sample step size 20)
# Worker 1/1 writing data to dopamine-acetylcholine-adaptive-trial-network/simulation/network-voltage-DA-ACh-trial-control.hdf5
# Program run time: 612.0s

# %% [markdown]
# Following the simulation, we plot the simulations individually using code from snudda. First, the dopamine-acetylcholine modulated simulation

# %%
from snudda.plotting.plot_traces import PlotTraces
import os

plot_offset = 0  
skip_time = 0  
num_traces_max = 10

network_path = "dopamine-acetylcholine-adaptive-trial-network"
network_file = os.path.join(network_path, "network-synapses.hdf5")
volt_file_name = os.path.join(network_path, "simulation", "network-voltage-DA-ACh-trial.hdf5")

pl = PlotTraces(output_file=volt_file_name,network_file=network_file)

pl.plot_trace_neuron_type(neuron_type="dSPN", num_traces=num_traces_max, offset=plot_offset, skip_time=skip_time)
pl.plot_trace_neuron_type(neuron_type="iSPN", num_traces=num_traces_max, offset=plot_offset, skip_time=skip_time)
# Out:
# Loading network info from dopamine-acetylcholine-adaptive-trial-network/network-synapses.hdf5
# Loading 14 neurons with 11153 synapses and 0 gap junctions
# Loading input info from dopamine-acetylcholine-adaptive-trial-network/input-spikes.hdf5
# Loading dopamine-acetylcholine-adaptive-trial-network/simulation/network-voltage-DA-ACh-trial.hdf5
# !!! Excluding first 0 s from the plot
# Plotting traces: [3, 5, 9, 11, 13]
# Plotted 5 traces (total 14)
# Saving to figure Network-voltage-trace--dSPN.pdf
# !!! Excluding first 0 s from the plot
# Plotting traces: [6, 7, 8, 10, 12]
# Plotted 5 traces (total 14)
# Saving to figure Network-voltage-trace--iSPN.pdf

# %% [markdown]
# Second, we plot the control simulation.

# %%
from snudda.plotting.plot_traces import PlotTraces
import os

plot_offset = 0  
skip_time = 0  
num_traces_max = 10

network_path = "dopamine-acetylcholine-adaptive-trial-network"
network_file = os.path.join(network_path, "network-synapses.hdf5")
volt_file_name = os.path.join(network_path, "simulation", "network-voltage-DA-ACh-trial-control.hdf5")

pl = PlotTraces(output_file=volt_file_name,network_file=network_file)

pl.plot_trace_neuron_type(neuron_type="dSPN", num_traces=num_traces_max, offset=plot_offset, skip_time=skip_time)
pl.plot_trace_neuron_type(neuron_type="iSPN", num_traces=num_traces_max, offset=plot_offset, skip_time=skip_time)
pl.plot_trace_neuron_type(neuron_type="DopaminergicAxon", num_traces=num_traces_max, offset=plot_offset, skip_time=skip_time)
# Out:
# Loading network info from dopamine-acetylcholine-adaptive-trial-network/network-synapses.hdf5
# Loading 14 neurons with 11153 synapses and 0 gap junctions
# Loading input info from dopamine-acetylcholine-adaptive-trial-network/input-spikes.hdf5
# Loading dopamine-acetylcholine-adaptive-trial-network/simulation/network-voltage-DA-ACh-trial-control.hdf5
# !!! Excluding first 0 s from the plot
# Plotting traces: [3, 5, 9, 11, 13]
# Plotted 5 traces (total 14)
# Saving to figure Network-voltage-trace--dSPN.pdf
# !!! Excluding first 0 s from the plot
# Plotting traces: [6, 7, 8, 10, 12]
# Plotted 5 traces (total 14)
# Saving to figure Network-voltage-trace--iSPN.pdf
# !!! Excluding first 0 s from the plot
# Plotting traces: [0, 1, 2, 4]
# Plotted 4 traces (total 14)
# Saving to figure Network-voltage-trace--DopaminergicAxon.pdf

# %% [markdown]
# We need load and plot control (black) and dopamine/acetylcholine modulated (red). We see clear effect on dSPN, which should depolarise upon dopamine modulation and the tonic depolarisation following muscarinic modulation, while iSPN do not have a clear effect from dopamine, but muscarinic modulation is tonic and depolarises the cell. FS have quite a large response to dopamine modulation, which is also seen in the network

# %%
os.makedirs(os.path.join("dopamine-acetylcholine-adaptive-trial-network","analysis"), exist_ok=True)

# %%
from code.plot import plot_dopamine_acetylcholine_control
from code.compare import compareTraces

network_path = "dopamine-acetylcholine-adaptive-trial-network"

fn = [os.path.join(network_path, "simulation","network-voltage-DA-ACh-trial-control.hdf5"),
     os.path.join(network_path ,"simulation", "network-voltage-DA-ACh-trial.hdf5")]

nf = [os.path.join(network_path, "network-synapses.hdf5"),
     os.path.join(network_path, "network-synapses.hdf5")]


kl = compareTraces(fileNames=fn,
                   networkFiles=nf,labels=["control", "DA-ACh"],colours=["black","red"])
# Out:
# Loading dopamine-acetylcholine-adaptive-trial-network/simulation/network-voltage-DA-ACh-trial-control.hdf5
# Loading dopamine-acetylcholine-adaptive-trial-network/simulation/network-voltage-DA-ACh-trial.hdf5

# %%
plot_dopamine_acetylcholine_control(kl,type_cell='dSPN')

# %%
plot_dopamine_acetylcholine_control(kl,type_cell='iSPN')
