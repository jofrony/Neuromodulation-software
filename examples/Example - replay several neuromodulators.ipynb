# %% [markdown]
# # Neuromodulation dopamine and acetylcholine - replay (single neuromodulator)

# %% [markdown]
# To simulate single neuromodulator in Snudda, firstly, the parameters from Neuromodcell have to been saved in modulations.json and placed in the model dircetory.
#
#
# To install snudda, follow the instructions at https://github.com/Hjorthmedh/Snudda/wiki/1.-User-installation
#
# Following installation, the code below will set up the network and the neuromodulatory modulation.

# %% [markdown]
# To set the $DATA parameter for snudda,

# %%
import os

os.environ["SNUDDA_DATA"] = 'data'

# %% [markdown]
# This should be set to the directory where neurons, synapses and other parameters for the network have been placed. Look at the 'data' directory for referenece

# %% [markdown]
# Set the directory for where the neurons for the striatum (in this example) are saved

# %%
neurons_dir = os.path.abspath('data/neurons/')

# %% [markdown]
# We wrote a specific neuromodulation init (based on snuddas init.py), to load the synapses which have had the modulation parameters included into the parameter sets.

# %%
from neuromodulationInit import neuromodulationInit

network_path = 'dopamine-acetylcholine-trial-network'
config_name= os.path.join(network_path,"network-config.json")
cnc = neuromodulationInit(config_file=config_name,random_seed=12345)

cnc.define_striatum_neuromodulation(num_dSPN=10,num_iSPN=10,num_FS=1,volume_type="cube",neurons_dir=neurons_dir)  
dirName = os.path.dirname(config_name)

if not os.path.exists(dirName):
    os.makedirs(dirName)

cnc.write_json(config_name)

# %% [markdown]
# Then we place the neurons within the network (as we are running this locally we are limiting the network to 21 neurons). We then detect the potential synapses (by appositions between axons and dendrites) and then remove (prune) to reproduce the reported connectivity.

# %%
from snudda.place import SnuddaPlace
sp = SnuddaPlace(network_path=network_path)
sp.parse_config()
sp.write_data()

from snudda.detect import SnuddaDetect

sd = SnuddaDetect(network_path=network_path)
sd.detect()

from snudda.prune import SnuddaPrune

sp = SnuddaPrune(network_path=network_path)
sp.prune()

from snudda.plotting.plot_network import PlotNetwork
pn = PlotNetwork(network_path)
pn.plot()
pn.close()

# %% [markdown]
# Following the assembly of the circuit, we set up the neuromodulatory transient which will be played through the network. Here, we simulate a dopamine and acetylcholine transients. The acetylcholine transient is tonic with an burst in the shape of an alpha function with time constant 300 ms which starts at 700 ms. The dopamine transient which starts after 500 ms in the shape of an alpha function with time constant 300 ms and maximum modulation 1 (i.e 100%). We then have to add the names of the ion channels which are modulated by dSPN, iSPN and FSN. The control simulation uses a bath application with modulation level at 0 for both acetylcholine and dopamine.

# %%
# Acetylcholine

from snudda.neuromodulation.modulation_network import Neuromodulation

nl = Neuromodulation()
nl.set_timestep(dt=0.025)

nl.set_modulation(neurotransmitter = 'acetylcholine', neurotransmitter_key = 'ACh')
nl.transient(neurotransmitter='acetylcholine',\
             method='alpha_background',\
             duration= 3000,\
             parameters={"tstart" : 700, "tonic" : 0.5, "gmax_increase" : 0.5, "tau" : 300})


nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'dSPN',\
                          section = 'soma',\
                          ion_channels = ['kaf_ms','kir_ms','cal12_ms','cal13_ms','can_ms','Im_ms'])
nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'dSPN',\
                          section = 'dendrite',\
                          ion_channels = ['kaf_ms','kir_ms','cal12_ms','cal13_ms'])
nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'dSPN',\
                          section = 'axon',\
                          ion_channels = [])

nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'iSPN',\
                          section = 'soma',\
                          ion_channels = ['kir_ms','cal12_ms','cal13_ms','can_ms'])
nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'iSPN',\
                          section = 'dendrite',\
                          ion_channels = ['kir_ms','cal12_ms','cal13_ms'])
nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'iSPN',\
                          section = 'axon',\
                          ion_channels = ['Im_ms'])

nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'FSN',\
                          section = 'soma',\
                          ion_channels = [])
nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'FSN',\
                          section = 'dendrite',\
                          ion_channels = [])
nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'FSN',\
                          section = 'axon',\
                          ion_channels = [])

nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'LTS',\
                          section = 'soma',\
                          ion_channels = ["im_lts","kir23_lts"])
nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'LTS',\
                          section = 'dendrite',\
                          ion_channels = ["im_lts","kir23_lts"])
nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'LTS',\
                          section = 'axon',\
                          ion_channels = [])

nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'ChIN',\
                          section = 'soma',\
                          ion_channels = ["cap_ch","cal_ch"])
nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'ChIN',\
                          section = 'dendrite',\
                          ion_channels = ["cap_ch","cal_ch","kir23_ch"])
nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'ChIN',\
                          section = 'axon',\
                          ion_channels = [])


# Dopamine

nl.set_modulation(neurotransmitter = 'dopamine', neurotransmitter_key = 'DA')
nl.transient(neurotransmitter='dopamine',\
             method='alpha',\
             duration= 3000,\
             parameters={"tstart" : 500, "gmax" : 1, "tau" : 300})


nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'dSPN',\
                          section = 'soma',\
                          ion_channels = ["cal12_ms","cal13_ms","kir_ms","kas_ms","naf_ms","can_ms"])
nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'dSPN',\
                          section = 'dendrite',\
                          ion_channels = ["kir_ms","kas_ms","kaf_ms","cal12_ms","cal13_ms"])
nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'dSPN',\
                          section = 'axon',\
                          ion_channels = [])

nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'iSPN',\
                          section = 'soma',\
                          ion_channels = ["kir_ms","kas_ms","kaf_ms","naf_ms","cal12_ms","cal13_ms", "can_ms","car_ms"])
nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'iSPN',\
                          section = 'dendrite',\
                          ion_channels = ["kir_ms","kas_ms","kaf_ms","naf_ms","cal12_ms","cal13_ms", "can_ms","car_ms"])
nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'iSPN',\
                          section = 'axon',\
                          ion_channels = ["kir_ms","kas_ms","kaf_ms","naf_ms","cal12_ms","cal13_ms", "can_ms","car_ms"])

nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'FSN',\
                          section = 'soma',\
                          ion_channels = ["naf_fs","kaf_fs","kas_fs","kir_fs"])
nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'FSN',\
                          section = 'dendrite',\
                          ion_channels = ["naf_fs","kaf_fs","kas_fs","kir_fs"])
nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'FSN',\
                          section = 'axon',\
                          ion_channels = [])

nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'LTS',\
                          section = 'soma',\
                          ion_channels = ["hd_lts","na3_lts"])
nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'LTS',\
                          section = 'dendrite',\
                          ion_channels = ["hd_lts"])
nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'LTS',\
                          section = 'axon',\
                          ion_channels = [])

nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'ChIN',\
                          section = 'soma',\
                          ion_channels = ["hcn12_ch"])
nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'ChIN',\
                          section = 'dendrite',\
                          ion_channels = ["hcn12_ch"])
nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'ChIN',\
                          section = 'axon',\
                          ion_channels = ["hcn12_ch"])


nl.save(dir_path='data/modulation',name='acetylcholine_dopamine.json')

# %%
# Acetylcholine

from snudda.neuromodulation.modulation_network import Neuromodulation

nl = Neuromodulation()
nl.set_timestep(dt=0.025)

nl.set_modulation(neurotransmitter = 'acetylcholine', neurotransmitter_key = 'ACh')
nl.transient(neurotransmitter='acetylcholine',\
             method='bath_application',\
             duration= 3000,\
             parameters={"gmax" : 0})


nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'dSPN',\
                          section = 'soma',\
                          ion_channels = ['kaf_ms','kir_ms','cal12_ms','cal13_ms','can_ms','Im_ms'])
nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'dSPN',\
                          section = 'dendrite',\
                          ion_channels = ['kaf_ms','kir_ms','cal12_ms','cal13_ms'])
nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'dSPN',\
                          section = 'axon',\
                          ion_channels = [])

nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'iSPN',\
                          section = 'soma',\
                          ion_channels = ['kir_ms','cal12_ms','cal13_ms','can_ms'])
nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'iSPN',\
                          section = 'dendrite',\
                          ion_channels = ['kir_ms','cal12_ms','cal13_ms'])
nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'iSPN',\
                          section = 'axon',\
                          ion_channels = ['Im_ms'])

nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'FSN',\
                          section = 'soma',\
                          ion_channels = [])
nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'FSN',\
                          section = 'dendrite',\
                          ion_channels = [])
nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'FSN',\
                          section = 'axon',\
                          ion_channels = [])

nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'LTS',\
                          section = 'soma',\
                          ion_channels = ["im_lts","kir23_lts"])
nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'LTS',\
                          section = 'dendrite',\
                          ion_channels = ["im_lts","kir23_lts"])
nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'LTS',\
                          section = 'axon',\
                          ion_channels = [])

nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'ChIN',\
                          section = 'soma',\
                          ion_channels = ["cap_ch","cal_ch"])
nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'ChIN',\
                          section = 'dendrite',\
                          ion_channels = ["cap_ch","cal_ch","kir23_ch"])
nl.ion_channel_modulation(neurotransmitter = 'acetylcholine',\
                          cell_type = 'ChIN',\
                          section = 'axon',\
                          ion_channels = [])


# Dopamine

nl.set_modulation(neurotransmitter = 'dopamine', neurotransmitter_key = 'DA')
nl.transient(neurotransmitter='dopamine',\
             method='bath_application',\
             duration= 3000,\
             parameters={"gmax" : 0})


nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'dSPN',\
                          section = 'soma',\
                          ion_channels = ["cal12_ms","cal13_ms","kir_ms","kas_ms","naf_ms","can_ms"])
nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'dSPN',\
                          section = 'dendrite',\
                          ion_channels = ["kir_ms","kas_ms","kaf_ms","cal12_ms","cal13_ms"])
nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'dSPN',\
                          section = 'axon',\
                          ion_channels = [])

nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'iSPN',\
                          section = 'soma',\
                          ion_channels = ["kir_ms","kas_ms","kaf_ms","naf_ms","cal12_ms","cal13_ms", "can_ms","car_ms"])
nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'iSPN',\
                          section = 'dendrite',\
                          ion_channels = ["kir_ms","kas_ms","kaf_ms","naf_ms","cal12_ms","cal13_ms", "can_ms","car_ms"])
nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'iSPN',\
                          section = 'axon',\
                          ion_channels = ["kir_ms","kas_ms","kaf_ms","naf_ms","cal12_ms","cal13_ms", "can_ms","car_ms"])

nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'FSN',\
                          section = 'soma',\
                          ion_channels = ["naf_fs","kaf_fs","kas_fs","kir_fs"])
nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'FSN',\
                          section = 'dendrite',\
                          ion_channels = ["naf_fs","kaf_fs","kas_fs","kir_fs"])
nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'FSN',\
                          section = 'axon',\
                          ion_channels = [])

nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'LTS',\
                          section = 'soma',\
                          ion_channels = ["hd_lts","na3_lts"])
nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'LTS',\
                          section = 'dendrite',\
                          ion_channels = ["hd_lts"])
nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'LTS',\
                          section = 'axon',\
                          ion_channels = [])

nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'ChIN',\
                          section = 'soma',\
                          ion_channels = ["hcn12_ch"])
nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'ChIN',\
                          section = 'dendrite',\
                          ion_channels = ["hcn12_ch"])
nl.ion_channel_modulation(neurotransmitter = 'dopamine',\
                          cell_type = 'ChIN',\
                          section = 'axon',\
                          ion_channels = ["hcn12_ch"])


nl.save(dir_path='data/modulation',name='acetylcholine_dopamine_control.json')

# %% [markdown]
# Compile the mechanisms used in the simulation

# %%
# !nrnivmodl mechanisms-modulation/

# %% [markdown]
# Restart the kernel (if the assembly and generation of input and simulation are in different notebooks - THIS STEP IS NOT NEEDED)

# %%
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
restartkernel()

# %%
import os
from snudda.input import SnuddaInput

os.environ["SNUDDA_DATA"] = 'data'

network_path = 'dopamine-acetylcholine-trial-network'

si = SnuddaInput(network_path=network_path, 
                 input_config_file=os.path.join("data","external_input","external-input-trial.json"),
                 verbose=False)
si.generate()

# %%
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
restartkernel()

# %% [markdown]
# We then simulate the dopamine and control case using Snudda

# %%
import os

os.environ["SNUDDA_DATA"] = 'data'

# %%
# !mpiexec -n 4 snudda simulate dopamine-acetylcholine-trial-network --time 3.0 --voltOut 'dopamine-acetylcholine-trial-network/simulation/network-voltage-DA-ACh-trial.csv' --neuromodulation data/modulation/acetylcholine_dopamine.json

# %%
# !mpiexec -n 4 snudda simulate dopamine-acetylcholine-trial-network --time 3.0 --voltOut 'dopamine-acetylcholine-trial-network/simulation/network-voltage-DA-ACh-trial-control.csv' --neuromodulation data/modulation/acetylcholine_dopamine_control.json

# %% [markdown]
# Following the simulation, we plot the simulations individually using code from snudda. First, the dopamine modulated simulation

# %%
from snudda.plotting.plot_traces import PlotTraces
import os

plot_offset = 0  
skip_time = 0  
num_traces_max = 10

network_path = 'dopamine-acetylcholine-trial-network'
network_file = os.path.join(network_path, "network-synapses.hdf5")
volt_file_name = os.path.join(network_path, "simulation", "network-voltage-DA-ACh-trial.csv")

pl = PlotTraces(file_name=volt_file_name,network_file=network_file)

pl.plotTraceNeuronType(neuron_type="dSPN", num_traces=num_traces_max, offset=plot_offset, skip_time=skip_time)
pl.plotTraceNeuronType(neuron_type="iSPN", num_traces=num_traces_max, offset=plot_offset, skip_time=skip_time)
pl.plotTraceNeuronType(neuron_type="FSN", num_traces=num_traces_max, offset=plot_offset, skip_time=skip_time)
# Out:
# Unable to guess ID, using 666.
# Loading 21 neurons with 215 synapses and 0 gap junctions
# !!! Excluding first 0s from the plot
# Plotting traces: [0, 1, 2, 3, 4, 5, 10, 12, 14, 17]
# Plotted 10 traces (total 21)
# Saving to figure Network-spikes-666-dSPN-colour.pdf
# !!! Excluding first 0s from the plot
# Plotting traces: [6, 8, 9, 11, 13, 15, 16, 18, 19, 20]
# Plotted 10 traces (total 21)
# Saving to figure Network-spikes-666-iSPN-colour.pdf
# !!! Excluding first 0s from the plot
# Plotting traces: [7]
# Plotted 1 traces (total 21)
# Saving to figure Network-spikes-666-FSN-colour.pdf

# %% [markdown]
# Second, we plot the control simulation.

# %%
from snudda.plotting.plot_traces import PlotTraces
import os

plot_offset = 0  
skip_time = 0  
num_traces_max = 10

network_path = 'dopamine-acetylcholine-trial-network'
network_file = os.path.join(network_path, "network-synapses.hdf5")
volt_file_name = os.path.join(network_path, "simulation", "network-voltage-DA-ACh-trial-control.csv")

pl = PlotTraces(file_name=volt_file_name,network_file=network_file)

pl.plotTraceNeuronType(neuron_type="dSPN", num_traces=num_traces_max, offset=plot_offset, skip_time=skip_time)
pl.plotTraceNeuronType(neuron_type="iSPN", num_traces=num_traces_max, offset=plot_offset, skip_time=skip_time)
pl.plotTraceNeuronType(neuron_type="FSN", num_traces=num_traces_max, offset=plot_offset, skip_time=skip_time)

# %% [markdown]
# We need load and plot control (black) and dopamine/acetylcholine modulated (red). We see clear effect on dSPN, which should depolarise upon dopamine modulation and the tonic depolarisation following muscarinic modulation, while iSPN do not have a clear effect from dopamine, but muscarinic modulation is tonic and depolarises the cell. FS have quite a large response to dopamine modulation, which is also seen in the network

# %%
from plot import plot_dopamine_acetylcholine_control
from compare import compareTraces

fn = ['dopamine-acetylcholine-trial-network/simulation/network-voltage-DA-ACh-trial-control.csv',\
     'dopamine-acetylcholine-trial-network/simulation/network-voltage-DA-ACh-trial.csv']

nf = ['dopamine-acetylcholine-trial-network/network-synapses.hdf5',\
     'dopamine-acetylcholine-trial-network/network-synapses.hdf5']


kl = compareTraces(fileNames=fn,\
                      networkFiles=nf,labels=['control','DA-ACh'],colours=['black','purple'])
# Out:
# Unable to guess ID, using 666.
# Loading 21 neurons with 215 synapses and 0 gap junctions
# Loading 21 neurons with 215 synapses and 0 gap junctions

# %%
plot_dopamine_acetylcholine_control(kl,type_cell='dSPN')

# %%
plot_dopamine_acetylcholine_control(kl,type_cell='iSPN')

# %%
plot_dopamine_acetylcholine_control(kl,type_cell='FSN')
