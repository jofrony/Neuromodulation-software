# %%
# !snudda init control --size 34

# %%
# !snudda place control

# %%
# !snudda detect control

# %%
# !snudda prune control

# %%
# !snudda input control --input Experiment-Simulation/external_input/external-input-dopamine-l4.json

# %%
# !nrnivmodl ../../../../Snudda/snudda/data/neurons/mechanisms/

# %%
# !mpiexec -n 4 snudda simulate control --time 0.3 --profile
# Out:
# Saving profile data to: profile-simulate.prof
# Using input file control/input-spikes.hdf5
# Saving profile data to: profile-simulate.prof
# Using input file control/input-spikes.hdf5
# args: Namespace(action='simulate', disable_gj=False, exportCoreNeuron=False, input_file=None, mech_dir=None, network_file=None, neuromodulation=None, path='control', profile=True, randomseed=None, spikes_out=None, time=0.3, verbose=False, volt_out=None)
# args: Namespace(action='simulate', disable_gj=False, exportCoreNeuron=False, input_file=None, mech_dir=None, network_file=None, neuromodulation=None, path='control', profile=True, randomseed=None, spikes_out=None, time=0.3, verbose=False, volt_out=None)
# Saving profile data to: profile-simulate.prof
# Using input file control/input-spikes.hdf5
# Saving profile data to: profile-simulate.prof
# ...
