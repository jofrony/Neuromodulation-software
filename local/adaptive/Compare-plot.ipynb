# %% [markdown]
# # Compare neuromodulation of DA-ACh and control

# %%
# %cd Experiment-Simulation
# Out:
# [Errno 2] No such file or directory: 'Experiment-Simulation'
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/striatal_network/synapse-wide/Experiment-Simulation

# %%
from project_wide.compare_plot_traces import comparePlotTraces

# %%
fn = ['Acetylcholine-Dopamine-concACh-concDA-network/simulation/network-voltage-ACh-DA-network.csv',\
      'Acetylcholine-Dopamine-concACh-concDA-network/simulation/network-voltage-ACh-DA-network-control.csv',
     'Acetylcholine-Dopamine-concACh-concDA-network/simulation/network-voltage-ACh-DA-network-burst.csv']

nf = ['Acetylcholine-Dopamine-concACh-concDA-network/network-synapses.hdf5',\
     'Acetylcholine-Dopamine-concACh-concDA-network/network-synapses.hdf5',\
     'Acetylcholine-Dopamine-concACh-concDA-network/network-synapses.hdf5']



nl = comparePlotTraces(fileNames=fn,\
                      networkFiles=nf,labels=['DA-ACh', 'control','burst'],colours=['red','black','purple'],save_dir='Compare-network/')
# Out:
# Unable to guess ID, using 666.
# Loading 7 neurons with 3088 synapses and 0 gap junctions
# Loading 7 neurons with 3088 synapses and 0 gap junctions
# Loading 7 neurons with 3088 synapses and 0 gap junctions

# %%
# %matplotlib notebook
plot_offset = 0  # -0.2
skip_time = 0  # 0.5
num_traces_max = 10

nl.plotTraceNeuronType(neuronType="dSPN", nTraces=10, offset=plot_offset, skipTime=skip_time)
nl.plotTraceNeuronType(neuronType="iSPN", nTraces=10, offset=plot_offset, skipTime=skip_time)
nl.plotTraceNeuronType(neuronType="FSN", nTraces=10, offset=plot_offset, skipTime=skip_time)
nl.plotTraceNeuronType(neuronType="LTS", nTraces=10, offset=plot_offset, skipTime=skip_time)
nl.plotTraceNeuronType(neuronType="ChIN", nTraces=10, offset=plot_offset, skipTime=skip_time)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Saving to figure Compare-network/figs/Network-spikes-666-dSPN-colour.svg
# <img src="data:image/png;base64,..." width="640">
# Saving to figure Compare-network/figs/Network-spikes-666-iSPN-colour.svg
# <img src="data:image/png;base64,..." width="640">
# Saving to figure Compare-network/figs/Network-spikes-666-FS-colour.svg
# <img src="data:image/png;base64,..." width="640">
# Saving to figure Compare-network/figs/Network-spikes-666-LTS-colour.svg
# <img src="data:image/png;base64,..." width="640">
# Saving to figure Compare-network/figs/Network-spikes-666-ChIN-colour.svg
