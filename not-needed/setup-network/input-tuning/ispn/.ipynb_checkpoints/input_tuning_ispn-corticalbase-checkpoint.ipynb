# %% [markdown]
# Different morphologies of the same neuron type might require different activation to reach comparable firing frequency. InputScaling simulates a network of a neuron type with different number of inputs, and different frequency to infer what level of input is needed.
#
# Here we look at the input to ```neuron_types="fs"```.
#
# During a simulation we can vary the input frequency, but not the number of inputs coupled to a neuron, so we use a set of ```num_replicas``` copies of each morphology, each receiving a different number of inputs from ```num_input_min``` to ```num_input_max``` of a given ```input_type``` (e.g. for striatum "cortical" or "thalamic").
#
# A set of input frequencies are tested, specified by ```input_frequency_range```, and each of these frequencies is run for ```input_duration``` seconds. In this example we create a small example, but we recommend that use use a longer input duration (e.g. 10 seconds, or possibly more).

# %%
import os
from snudda.input.input_tuning import InputTuning
network_path = os.path.join("networks", "input_tuning")
input_tuning = InputTuning(network_path)

# %% [markdown]
# We create a network without any synapses and connect different number of external inputs to the neurons. Each neuron then receives a range of input frequencies.

# %%
path = os.path.abspath('../../Neuromodulation/single_cell_models/HBP-2021Q1/striatum')

# %%
neurons_path = os.path.join(path)
input_tuning.setup_network(neurons_path=neurons_path, 
                           num_replicas=5,
                           neuron_types="ispn")
input_tuning.setup_input(input_type="cortical",  # eg. "cortical" or "thalamic"
                         num_input_min=100,
                         num_input_max=500,
                         input_duration=3.0,
                         input_frequency_range=[1.0, 2.0])
# Out:
# Skipping neuron type dspn
# Skipping neuron type fs
# Found 4 neurons in /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Neuromodulation/single_cell_models/HBP-2021Q1/striatum/ispn
# Writing network config file to networks/input_tuning/network-config.json
# No d_view specified, running distribute neurons in serial
# No connections specified in connectivity_distribution.
# No output file created, no synapses exist?
# Creating symbolic link to MERGE file instead
# networks/input_tuning/network-synapses.hdf5 -> network-putative-synapses-MERGED.hdf5
# Using cortical synapse density for input.
# Loading 20 neurons with 0 synapses and 0 gap junctions
# Writing spikes to networks/input_tuning/input.hdf5

# %%
from snudda.input import SnuddaInput

si = SnuddaInput(input_config_file=input_tuning.input_config_file,
                 hdf5_network_file=input_tuning.network_file,
                 spike_data_filename=input_tuning.input_spikes_file,
                 time=input_tuning.max_time)
si.generate()
# Out:
# Writing spikes to networks/input_tuning/input.hdf5

# %%
# !nrnivmodl mechanisms-ispn/
# Out:
# Creating x86_64 directory for .o files.
#
# /home/jofrony/Documents/Repositories/BasalGangliaExperiments/Input_tuning/ispn
# ls: cannot access 'mechanisms-ispn//*.inc': No such file or directory
# mechanisms-ispn//bk.mod mechanisms-ispn//cadyn.mod mechanisms-ispn//cal12.mod mechanisms-ispn//cal13.mod mechanisms-ispn//caldyn.mod mechanisms-ispn//can.mod mechanisms-ispn//caq.mod mechanisms-ispn//car.mod mechanisms-ispn//cat32.mod mechanisms-ispn//cat33.mod mechanisms-ispn//concACh.mod mechanisms-ispn//concDA.mod mechanisms-ispn//Im.mod mechanisms-ispn//kaf.mod mechanisms-ispn//kas.mod mechanisms-ispn//kdr.mod mechanisms-ispn//kir.mod mechanisms-ispn//naf.mod mechanisms-ispn//NO.mod mechanisms-ispn//sk.mod mechanisms-ispn//tmgabaa.mod mechanisms-ispn//tmglut_M1RH_D1.mod mechanisms-ispn//tmglut.mod mechanisms-ispn//vecevent.mod
# bk.mod cadyn.mod cal12.mod cal13.mod caldyn.mod can.mod caq.mod car.mod cat32.mod cat33.mod concACh.mod concDA.mod Im.mod kaf.mod kas.mod kdr.mod kir.mod naf.mod NO.mod sk.mod tmgabaa.mod tmglut_M1RH_D1.mod tmglut.mod vecevent.mod
# "/usr/local/nrn/x86_64/bin/nocmodl" bk
# "/usr/local/nrn/x86_64/bin/nocmodl" cadyn
# "/usr/local/nrn/x86_64/bin/nocmodl" cal12
# "/usr/local/nrn/x86_64/bin/nocmodl" cal13
# Translating bk.mod into bk.c
# Translating cal12.mod into cal12.c
# Translating cadyn.mod into cadyn.c
# Translating cal13.mod into cal13.c
# Thread Safe
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o bk.lo bk.c
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cadyn.lo cadyn.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cal12.lo cal12.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cal13.lo cal13.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c bk.c  -fPIC -DPIC -o .libs/bk.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cal13.c  -fPIC -DPIC -o .libs/cal13.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cadyn.c  -fPIC -DPIC -o .libs/cadyn.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cal12.c  -fPIC -DPIC -o .libs/cal12.o
# "/usr/local/nrn/x86_64/bin/nocmodl" caldyn
# Translating caldyn.mod into caldyn.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o caldyn.lo caldyn.c
# "/usr/local/nrn/x86_64/bin/nocmodl" can
# Translating can.mod into can.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o can.lo can.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c caldyn.c  -fPIC -DPIC -o .libs/caldyn.o
# "/usr/local/nrn/x86_64/bin/nocmodl" caq
# Translating caq.mod into caq.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o caq.lo caq.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c can.c  -fPIC -DPIC -o .libs/can.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c caq.c  -fPIC -DPIC -o .libs/caq.o
# "/usr/local/nrn/x86_64/bin/nocmodl" car
# Translating car.mod into car.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o car.lo car.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c car.c  -fPIC -DPIC -o .libs/car.o
# "/usr/local/nrn/x86_64/bin/nocmodl" cat32
# Translating cat32.mod into cat32.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cat32.lo cat32.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cat32.c  -fPIC -DPIC -o .libs/cat32.o
# "/usr/local/nrn/x86_64/bin/nocmodl" cat33
# Translating cat33.mod into cat33.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cat33.lo cat33.c
# "/usr/local/nrn/x86_64/bin/nocmodl" concACh
# Translating concACh.mod into concACh.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o concACh.lo concACh.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c concACh.c  -fPIC -DPIC -o .libs/concACh.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cat33.c  -fPIC -DPIC -o .libs/cat33.o
# "/usr/local/nrn/x86_64/bin/nocmodl" concDA
# Translating concDA.mod into concDA.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o concDA.lo concDA.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c concDA.c  -fPIC -DPIC -o .libs/concDA.o
# "/usr/local/nrn/x86_64/bin/nocmodl" Im
# Translating Im.mod into Im.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o Im.lo Im.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c Im.c  -fPIC -DPIC -o .libs/Im.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kaf
# "/usr/local/nrn/x86_64/bin/nocmodl" kas
# Translating kaf.mod into kaf.c
# Translating kas.mod into kas.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kas.lo kas.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kaf.lo kaf.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kas.c  -fPIC -DPIC -o .libs/kas.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kaf.c  -fPIC -DPIC -o .libs/kaf.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kdr
# Translating kdr.mod into kdr.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kdr.lo kdr.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kdr.c  -fPIC -DPIC -o .libs/kdr.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kir
# Translating kir.mod into kir.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kir.lo kir.c
# "/usr/local/nrn/x86_64/bin/nocmodl" naf
# Translating naf.mod into naf.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o naf.lo naf.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kir.c  -fPIC -DPIC -o .libs/kir.o
# "/usr/local/nrn/x86_64/bin/nocmodl" NO
# Translating NO.mod into NO.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o NO.lo NO.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c naf.c  -fPIC -DPIC -o .libs/naf.o
# "/usr/local/nrn/x86_64/bin/nocmodl" sk
# Translating sk.mod into sk.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o sk.lo sk.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c NO.c  -fPIC -DPIC -o .libs/NO.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c sk.c  -fPIC -DPIC -o .libs/sk.o
# "/usr/local/nrn/x86_64/bin/nocmodl" tmgabaa
# Translating tmgabaa.mod into tmgabaa.c
# Notice: VERBATIM blocks are not thread safe
# Notice: scop_random is not thread safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o tmgabaa.lo tmgabaa.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c tmgabaa.c  -fPIC -DPIC -o .libs/tmgabaa.o
# "/usr/local/nrn/x86_64/bin/nocmodl" tmglut_M1RH_D1
# Translating tmglut_M1RH_D1.mod into tmglut_M1RH_D1.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o tmglut_M1RH_D1.lo tmglut_M1RH_D1.c
# "/usr/local/nrn/x86_64/bin/nocmodl" tmglut
# Translating tmglut.mod into tmglut.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o tmglut.lo tmglut.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c tmglut_M1RH_D1.c  -fPIC -DPIC -o .libs/tmglut_M1RH_D1.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c tmglut.c  -fPIC -DPIC -o .libs/tmglut.o
# "/usr/local/nrn/x86_64/bin/nocmodl" vecevent
# Translating vecevent.mod into vecevent.c
# Notice: ARTIFICIAL_CELL is a synonym for POINT_PROCESS which hints that it
# only affects and is affected by discrete events. As such it is not
# located in a section and is not associated with an integrator
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o vecevent.lo vecevent.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c vecevent.c  -fPIC -DPIC -o .libs/vecevent.o
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o mod_func.lo mod_func.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c mod_func.c  -fPIC -DPIC -o .libs/mod_func.o
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=link mpicc -module  -g -O2    -o libnrnmech.la -rpath "/usr/local/nrn/x86_64/lib"  bk.lo cadyn.lo cal12.lo cal13.lo caldyn.lo can.lo caq.lo car.lo cat32.lo cat33.lo concACh.lo concDA.lo Im.lo kaf.lo kas.lo kdr.lo kir.lo naf.lo NO.lo sk.lo tmgabaa.lo tmglut_M1RH_D1.lo tmglut.lo vecevent.lo mod_func.lo  -L"/usr/local/nrn/x86_64/lib" -lnrnoc -loc -lmemacs -lnrnmpi -lscopmath -lsparse13 -lreadline -lncurses -ltinfo -L"/usr/local/nrn/x86_64/lib" -lnrniv -livoc -lneuron_gnu -lmeschach -lsundials       -lm -ldl
# libtool: link: mpicc -shared  -fPIC -DPIC  .libs/bk.o .libs/cadyn.o .libs/cal12.o .libs/cal13.o .libs/caldyn.o .libs/can.o .libs/caq.o .libs/car.o .libs/cat32.o .libs/cat33.o .libs/concACh.o .libs/concDA.o .libs/Im.o .libs/kaf.o .libs/kas.o .libs/kdr.o .libs/kir.o .libs/naf.o .libs/NO.o .libs/sk.o .libs/tmgabaa.o .libs/tmglut_M1RH_D1.o .libs/tmglut.o .libs/vecevent.o .libs/mod_func.o   -Wl,-rpath -Wl,/usr/local/nrn/x86_64/lib -Wl,-rpath -Wl,/usr/local/nrn/x86_64/lib -L/usr/local/nrn/x86_64/lib /usr/local/nrn/x86_64/lib/libnrnoc.so /usr/local/nrn/x86_64/lib/liboc.so -lX11 /usr/local/nrn/x86_64/lib/libmemacs.so /usr/local/nrn/x86_64/lib/libnrnmpi.so /usr/local/nrn/x86_64/lib/libscopmath.so /usr/local/nrn/x86_64/lib/libsparse13.so /usr/local/nrn/x86_64/lib/libreadline.so -lncurses -ltinfo /usr/local/nrn/x86_64/lib/libnrniv.so /usr/local/nrn/x86_64/lib/libivoc.so /usr/local/nrn/x86_64/lib/libneuron_gnu.so /usr/local/nrn/x86_64/lib/libmeschach.so /usr/local/nrn/x86_64/lib/libsundials.so -lm -ldl  -g -O2   -Wl,-soname -Wl,libnrnmech.so.0 -o .libs/libnrnmech.so.0.0.0
# libtool: link: (cd ".libs" && rm -f "libnrnmech.so.0" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so.0")
# libtool: link: (cd ".libs" && rm -f "libnrnmech.so" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so")
# libtool: link: ( cd ".libs" && rm -f "libnrnmech.la" && ln -s "../libnrnmech.la" "libnrnmech.la" )
# Successfully created x86_64/special

# %% [markdown]
# For large runs, to simulate in parallel use:
#
# ```mpiexec -n 4 python3 ../../snudda/input/input_tuning.py simulate networks/input_tuning/```
#
# Below we just run it in serial in the notebook.

# %%
# !mpiexec -n 4 python3 ../../../Snudda/snudda/input/input_tuning.py simulate networks/input_tuning
# Out:
# numprocs=4
# Run simulation...
# Tip, to run in parallel on your local machine use: mpiexec -n 4 python3 tuning/input_tuning.py simulate <yournetworkhere>
# Creating save/traces
# Run simulation...
# Tip, to run in parallel on your local machine use: mpiexec -n 4 python3 tuning/input_tuning.py simulate <yournetworkhere>
# Run simulation...
# Tip, to run in parallel on your local machine use: mpiexec -n 4 python3 tuning/input_tuning.py simulate <yournetworkhere>
# Run simulation...
# Tip, to run in parallel on your local machine use: mpiexec -n 4 python3 tuning/input_tuning.py simulate <yournetworkhere>
# Loading 20 neurons with 0 synapses and 0 gap junctions
# Loading 20 neurons with 0 synapses and 0 gap junctions
# Loading 20 neurons with 0 synapses and 0 gap junctions
# Loading 20 neurons with 0 synapses and 0 gap junctions
# Running simulation for 6000.0 ms.
# Running simulation for 6000.0 ms.
# Running simulation for 6000.0 ms.
# Running simulation for 6000.0 ms.
# Running simulation for 6.0 s
# Running simulation for 6.0 s
# Running simulation for 6.0 s
# Running simulation for 6.0 s
# 1% done. Elapsed: 6.2 s, estimated time left: 611.0 s
# 16% done. Elapsed: 111.5 s, estimated time left: 585.3 s
# 29% done. Elapsed: 213.0 s, estimated time left: 521.5 s
# 40% done. Elapsed: 316.0 s, estimated time left: 474.0 s
# 53% done. Elapsed: 424.3 s, estimated time left: 376.3 s
# 67% done. Elapsed: 530.7 s, estimated time left: 261.4 s
# 80% done. Elapsed: 634.4 s, estimated time left: 158.6 s
# 94% done. Elapsed: 739.8 s, estimated time left: 47.2 s
# Simulation run time: 804.4243463620005 s
# Simulation done, saving output
# Writing spike times to networks/input_tuning/output_spikes.txt
# Simulation run time: 804.3684772060005 s
# Simulation done, saving output
# Writing spike times to networks/input_tuning/output_spikes.txt
# Simulation run time: 804.5712738480015 s
# Simulation done, saving output
# Writing spike times to networks/input_tuning/output_spikes.txt
# Simulation run time: 804.6035051670005 s
# Simulation done, saving output
# Writing spike times to networks/input_tuning/output_spikes.txt
# Program run time: 806.6929176379999
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/bluepyopt/ephys/simulators.py:74: UserWarning: Unable to find Neuron hoc shared library in /usr/local/nrn/lib/python/neuron, not disabling banner
#   'not disabling banner' % nrnpy_path)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/bluepyopt/ephys/simulators.py:74: UserWarning: Unable to find Neuron hoc shared library in /usr/local/nrn/lib/python/neuron, not disabling banner
#   'not disabling banner' % nrnpy_path)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/bluepyopt/ephys/simulators.py:74: UserWarning: Unable to find Neuron hoc shared library in /usr/local/nrn/lib/python/neuron, not disabling banner
#   'not disabling banner' % nrnpy_path)
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/bluepyopt/ephys/simulators.py:74: UserWarning: Unable to find Neuron hoc shared library in /usr/local/nrn/lib/python/neuron, not disabling banner
#   'not disabling banner' % nrnpy_path)

# %%
input_tuning.simulate()

# %%
input_tuning.analyse_results(show_plots=True)
# Out:
# Loading 20 neurons with 0 synapses and 0 gap junctions
# To plot traces:
# python3 plotting/Network_plot_traces.py networks/input_tuningoutput_volt.txt networks/input_tuningnetwork-synapses.hdf5
